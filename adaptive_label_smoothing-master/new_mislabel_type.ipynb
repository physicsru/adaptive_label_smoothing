# %%
# -*- coding:utf-8 -*-
import os
import torch 
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision.transforms as transforms
from data.cifar import CIFAR10, CIFAR100
from data.mnist import MNIST
from model import CNN
import argparse, sys
import numpy as np
import datetime
import shutil

# %%
def train(args, model, device, train_loader, optimizer, epoch, eps=9.9):
    model.train()
   # for batch_idx, (data, target, idx, is_pure, is_corrupt) in enumerate(train_loader):
    for batch_idx, (data, target,index) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        output = F.softmax(output, dim=1)
        output = output + (output[:, 10] / eps).unsqueeze(1)
        output.log_()
        
        loss = F.nll_loss(output, target)
        
        loss.backward()
        
        optimizer.step()

        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    return loss.item()

def test(args, model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    acc = []
    with torch.no_grad():
        for data, target, index in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output[:,:10].argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    acc=100. * correct / len(test_loader.dataset);
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        acc))
    return acc

# %%
def main():
    parser = argparse.ArgumentParser(description='PyTorch MNIST Example')
    
    parser.add_argument('--result_dir', type = str, help = 'dir to save result txt files', default = 'results/')
    parser.add_argument('--noise_rate', type = float, help = 'corruption rate, should be less than 1', default = 0.5)
    parser.add_argument('--forget_rate', type = float, help = 'forget rate', default = None)
    parser.add_argument('--noise_type', type = str, help='[pairflip, symmetric]', default='symmetric')
    parser.add_argument('--num_gradual', type = int, default = 10, help='how many epochs for linear drop rate, can be 5, 10, 15. This parameter is equal to Tk for R(T) in Co-teaching paper.')
    parser.add_argument('--exponent', type = float, default = 1, help='exponent of the forget rate, can be 0.5, 1, 2. This parameter is equal to c in Tc for R(T) in Co-teaching paper.')
    parser.add_argument('--top_bn', action='store_true')
    parser.add_argument('--dataset', type = str, help = 'mnist, cifar10, or cifar100', default = 'mnist')
    parser.add_argument('--n_epoch', type=int, default=200)
    parser.add_argument('--seed', type=int, default=1)
    parser.add_argument('--print_freq', type=int, default=50)
    parser.add_argument('--num_workers', type=int, default=4, help='how many subprocesses to use for data loading')
    parser.add_argument('--num_iter_per_epoch', type=int, default=400)
    parser.add_argument('--epoch_decay_start', type=int, default=80)

    
    parser.add_argument('--batch-size', type=int, default=1000, metavar='N',
                        help='input batch size for training (default: 256)')
    parser.add_argument('--test-batch-size', type=int, default=4000, metavar='N',
                        help='input batch size for testing (default: 1000)')
    parser.add_argument('--lr', type=float, default=0.005, metavar='LR',
                        help='learning rate (default: 0.01)')
    parser.add_argument('--momentum', type=float, default=0.9, metavar='M',
                        help='SGD momentum (default: 0.5)')
    parser.add_argument('--no-cuda', action='store_true', default=False,
                        help='disables CUDA training')
    parser.add_argument('--log-interval', type=int, default=100, metavar='N',
                        help='how many batches to wait before logging training status')
    
    parser.add_argument('--save-model', action='store_true', default=False,
                        help='For Saving the current Model')
    args = parser.parse_args()
    
    torch.manual_seed(args.seed)
    torch.cuda.manual_seed(args.seed)
    
    batch_size=args.batch_size
    
    if args.dataset=='mnist':
        input_channel=1
        num_classes=10
        args.top_bn = False
        args.epoch_decay_start = 80
        args.n_epoch = 200
        train_dataset = MNIST(root='./data/',
                                    download=True,  
                                    train=True, 
                                    transform=transforms.ToTensor(),
                                    noise_type=args.noise_type,
                                    noise_rate=args.noise_rate
                             )

        test_dataset = MNIST(root='./data/',
                                   download=True,  
                                   train=False, 
                                   transform=transforms.ToTensor(),
                                   noise_type=args.noise_type,
                                   noise_rate=args.noise_rate
                            )
    
    if args.dataset=='cifar10':
        input_channel=3
        num_classes=10
        args.top_bn = False
        args.epoch_decay_start = 80
        args.n_epoch = 200
        train_dataset = CIFAR10(root='./data/',
                                    download=True,  
                                    train=True, 
                                    transform=transforms.ToTensor(),
                                    noise_type=args.noise_type,
                                    noise_rate=args.noise_rate
                               )

        test_dataset = CIFAR10(root='./data/',
                                    download=True,  
                                    train=False, 
                                    transform=transforms.ToTensor(),
                                    noise_type=args.noise_type,
                                    noise_rate=args.noise_rate
                              )

    if args.dataset=='cifar100':
        input_channel=3
        num_classes=100
        args.top_bn = False
        args.epoch_decay_start = 100
        args.n_epoch = 200
        train_dataset = CIFAR100(root='./data/',
                                    download=True,  
                                    train=True, 
                                    transform=transforms.ToTensor(),
                                    noise_type=args.noise_type,
                                    noise_rate=args.noise_rate
                                )

        test_dataset = CIFAR100(root='./data/',
                                    download=True,  
                                    train=False, 
                                    transform=transforms.ToTensor(),
                                    noise_type=args.noise_type,
                                    noise_rate=args.noise_rate
                                )

    if args.forget_rate is None:
        forget_rate=args.noise_rate
    else:
        forget_rate=args.forget_rate

    noise_or_not = train_dataset.noise_or_not
    # Data Loader (Input Pipeline)
    print('loading dataset...')
    train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                               batch_size=batch_size, 
                                               num_workers=args.num_workers,
                                               drop_last=True,
                                               shuffle=True)
    
    test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                              batch_size=batch_size, 
                                              num_workers=args.num_workers,
                                              drop_last=True,
                                              shuffle=False)
    # Define models
    print('building model...')
    cnn1 = CNN(input_channel=input_channel, n_outputs=num_classes+1)
    cnn1.cuda()
    print(cnn1.parameters)
    #optimizer1 = torch.optim.SGD(cnn1.parameters(), lr=learning_rate)
    optimizer = torch.optim.SGD(cnn1.parameters(), lr=args.lr, momentum=args.momentum)
    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    acc=[]
    loss=[]
    loss_pure=[]
    loss_corrupt=[]
    for epoch in range(1, args.n_epoch + 1):
#         if epoch<20:
#             loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=9.5))
#         else:
#             loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=5))
        #loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=9.3))
        l1=train(args, cnn1, device, train_loader, optimizer, epoch,eps=7.5)
        loss.append(l1)
        
        acc.append(test(args, cnn1, device, test_loader))
    name=str(args.dataset)+" "+str(args.noise_type)+" "+str(args.noise_rate)
    np.save(name+"acc.npy",acc)
    np.save(name+"loss.npy",loss)

# %%
torch.cuda.set_device(0)#eps=9.1
sys.argv = ['-f']
main()
# Out:
# 9 10
# 60000
# Actual noise 0.50
# [[0.5        0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.5        0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.5        0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.5        0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.5        0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.5
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.5        0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.5        0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.5        0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.5       ]]
# loading dataset...
# building model...
# <bound method Module.parameters of CNN(
#   (c1): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c7): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1))
#   (c8): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1))
#   (c9): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#   (l_c1): Linear(in_features=128, out_features=11, bias=True)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )>
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.324006
#
# Test set: Average loss: -1.5522, Accuracy: 9175/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.875968
#
# Test set: Average loss: -1.7408, Accuracy: 9340/10000 (93%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 1.825671
#
# Test set: Average loss: -1.8721, Accuracy: 9411/10000 (94%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 1.814222
#
# Test set: Average loss: -1.8660, Accuracy: 9425/10000 (94%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 1.768676
#
# Test set: Average loss: -1.9020, Accuracy: 9431/10000 (94%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 1.838556
#
# Test set: Average loss: -1.9320, Accuracy: 9454/10000 (95%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 1.774361
#
# Test set: Average loss: -2.0922, Accuracy: 9448/10000 (94%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 1.790709
#
# Test set: Average loss: -2.1985, Accuracy: 9473/10000 (95%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 1.760036
#
# Test set: Average loss: -2.2733, Accuracy: 9476/10000 (95%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 1.692303
#
# Test set: Average loss: -2.3412, Accuracy: 9472/10000 (95%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 1.795487
#
# Test set: Average loss: -2.4095, Accuracy: 9476/10000 (95%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 1.805616
#
# Test set: Average loss: -2.5350, Accuracy: 9487/10000 (95%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 1.793132
#
# Test set: Average loss: -2.5347, Accuracy: 9469/10000 (95%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 1.703639
#
# Test set: Average loss: -2.5545, Accuracy: 9490/10000 (95%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 1.703252
#
# Test set: Average loss: -2.6413, Accuracy: 9474/10000 (95%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 1.756036
#
# Test set: Average loss: -2.6934, Accuracy: 9464/10000 (95%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 1.749778
#
# Test set: Average loss: -2.7804, Accuracy: 9461/10000 (95%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 1.833566
#
# Test set: Average loss: -2.7126, Accuracy: 9452/10000 (95%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 1.715285
#
# Test set: Average loss: -2.7326, Accuracy: 9449/10000 (94%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 1.746855
#
# Test set: Average loss: -2.7725, Accuracy: 9433/10000 (94%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 1.740503
#
# Test set: Average loss: -2.8001, Accuracy: 9442/10000 (94%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 1.698172
#
# Test set: Average loss: -2.8284, Accuracy: 9428/10000 (94%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 1.657122
#
# Test set: Average loss: -2.8160, Accuracy: 9406/10000 (94%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 1.672548
#
# Test set: Average loss: -2.8952, Accuracy: 9405/10000 (94%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 1.647664
#
# Test set: Average loss: -2.7805, Accuracy: 9339/10000 (93%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 1.597794
#
# Test set: Average loss: -2.8078, Accuracy: 9312/10000 (93%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 1.663330
#
# Test set: Average loss: -2.8523, Accuracy: 9273/10000 (93%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 1.681581
#
# Test set: Average loss: -2.7742, Accuracy: 9216/10000 (92%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 1.643630
#
# Test set: Average loss: -2.8896, Accuracy: 9266/10000 (93%)
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 1.636016
#
# Test set: Average loss: -2.7671, Accuracy: 9156/10000 (92%)
#
# Train Epoch: 31 [0/60000 (0%)]	Loss: 1.682085
#
# Test set: Average loss: -2.8505, Accuracy: 9125/10000 (91%)
#
# Train Epoch: 32 [0/60000 (0%)]	Loss: 1.569000
#
# Test set: Average loss: -2.9418, Accuracy: 9036/10000 (90%)
#
# Train Epoch: 33 [0/60000 (0%)]	Loss: 1.681482
#
# Test set: Average loss: -2.8063, Accuracy: 8952/10000 (90%)
#
# Train Epoch: 34 [0/60000 (0%)]	Loss: 1.603719
#
# Test set: Average loss: -2.8256, Accuracy: 8909/10000 (89%)
#
# Train Epoch: 35 [0/60000 (0%)]	Loss: 1.569163
#
# Test set: Average loss: -2.8439, Accuracy: 8828/10000 (88%)
#
# Train Epoch: 36 [0/60000 (0%)]	Loss: 1.526582
#
# Test set: Average loss: -2.8129, Accuracy: 8628/10000 (86%)
#
# Train Epoch: 37 [0/60000 (0%)]	Loss: 1.532507
#
# Test set: Average loss: -3.0079, Accuracy: 8791/10000 (88%)
#
# Train Epoch: 38 [0/60000 (0%)]	Loss: 1.486988
#
# Test set: Average loss: -2.8153, Accuracy: 8556/10000 (86%)
#
# Train Epoch: 39 [0/60000 (0%)]	Loss: 1.506086
#
# Test set: Average loss: -2.9648, Accuracy: 8522/10000 (85%)
#
# Train Epoch: 40 [0/60000 (0%)]	Loss: 1.498614
#
# Test set: Average loss: -2.7740, Accuracy: 8279/10000 (83%)
#
# Train Epoch: 41 [0/60000 (0%)]	Loss: 1.469692
#
# Test set: Average loss: -2.8415, Accuracy: 8364/10000 (84%)
#
# Train Epoch: 42 [0/60000 (0%)]	Loss: 1.469941
#
# Test set: Average loss: -2.8282, Accuracy: 8143/10000 (81%)
#
# Train Epoch: 43 [0/60000 (0%)]	Loss: 1.409548
#
# Test set: Average loss: -2.7365, Accuracy: 7819/10000 (78%)
#
# Train Epoch: 44 [0/60000 (0%)]	Loss: 1.359091
#
# Test set: Average loss: -2.9044, Accuracy: 8010/10000 (80%)
#
# Train Epoch: 45 [0/60000 (0%)]	Loss: 1.369638
#
# Test set: Average loss: -2.9953, Accuracy: 8045/10000 (80%)
#
# Train Epoch: 46 [0/60000 (0%)]	Loss: 1.332063
#
# Test set: Average loss: -2.7416, Accuracy: 7511/10000 (75%)
#
# Train Epoch: 47 [0/60000 (0%)]	Loss: 1.359409
#
# Test set: Average loss: -3.0295, Accuracy: 7661/10000 (77%)
#
# Train Epoch: 48 [0/60000 (0%)]	Loss: 1.264059
#
# Test set: Average loss: -2.9671, Accuracy: 7428/10000 (74%)
#
# Train Epoch: 49 [0/60000 (0%)]	Loss: 1.200370
#
# Test set: Average loss: -2.8564, Accuracy: 7342/10000 (73%)
#
# Train Epoch: 50 [0/60000 (0%)]	Loss: 1.174762
#
# Test set: Average loss: -2.7916, Accuracy: 7006/10000 (70%)
#
# Train Epoch: 51 [0/60000 (0%)]	Loss: 1.194375
# Test set: Average loss: -2.8985, Accuracy: 7024/10000 (70%)
#
# Train Epoch: 52 [0/60000 (0%)]	Loss: 1.165180
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1b295aaa95f9> in <module>()
#       1 torch.cuda.set_device(0)
#       2 sys.argv = ['-f']
# ----> 3 main()
#
# <ipython-input-13-88209d2434e7> in main()
#     145 #             loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=5))
#     146         #loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=9.3))
# --> 147         l1=train(args, cnn1, device, train_loader, optimizer, epoch,eps=9.1)
#     148         loss.append(l1)
#     149
#
# <ipython-input-2-91eba868756c> in train(args, model, device, train_loader, optimizer, epoch, eps)
#       3    # for batch_idx, (data, target, idx, is_pure, is_corrupt) in enumerate(train_loader):
#       4     for batch_idx, (data, target,index) in enumerate(train_loader):
# ----> 5         data, target = data.to(device), target.to(device)
#       6         optimizer.zero_grad()
#       7         output = model(data)
#
# KeyboardInterrupt:

# %%
torch.cuda.set_device(0)#eps=8.5
sys.argv = ['-f']
main()
# Out:
# 9 10
# 60000
# Actual noise 0.50
# [[0.5        0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.5        0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.5        0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.5        0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.5        0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.5
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.5        0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.5        0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.5        0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.5       ]]
# loading dataset...
# building model...
# <bound method Module.parameters of CNN(
#   (c1): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c7): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1))
#   (c8): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1))
#   (c9): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#   (l_c1): Linear(in_features=128, out_features=11, bias=True)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )>
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.317935
#
# Test set: Average loss: -1.5585, Accuracy: 9181/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.867872
#
# Test set: Average loss: -1.7608, Accuracy: 9355/10000 (94%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 1.813026
#
# Test set: Average loss: -1.9081, Accuracy: 9423/10000 (94%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 1.795885
#
# Test set: Average loss: -2.0328, Accuracy: 9436/10000 (94%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 1.735251
#
# Test set: Average loss: -2.2277, Accuracy: 9442/10000 (94%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 1.793298
#
# Test set: Average loss: -2.4329, Accuracy: 9460/10000 (95%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 1.733676
#
# Test set: Average loss: -2.6175, Accuracy: 9466/10000 (95%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 1.743527
#
# Test set: Average loss: -2.8022, Accuracy: 9482/10000 (95%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 1.719600
#
# Test set: Average loss: -2.9125, Accuracy: 9482/10000 (95%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 1.644861
#
# Test set: Average loss: -3.0000, Accuracy: 9481/10000 (95%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 1.755866
#
# Test set: Average loss: -3.0914, Accuracy: 9483/10000 (95%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 1.766344
#
# Test set: Average loss: -3.1982, Accuracy: 9487/10000 (95%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 1.754404
#
# Test set: Average loss: -3.2529, Accuracy: 9495/10000 (95%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 1.668275
#
# Test set: Average loss: -3.2706, Accuracy: 9500/10000 (95%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 1.677232
#
# Test set: Average loss: -3.3617, Accuracy: 9502/10000 (95%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 1.725234
#
# Test set: Average loss: -3.4338, Accuracy: 9486/10000 (95%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 1.718050
#
# Test set: Average loss: -3.5409, Accuracy: 9483/10000 (95%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 1.809122
#
# Test set: Average loss: -3.4603, Accuracy: 9481/10000 (95%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 1.681905
#
# Test set: Average loss: -3.4842, Accuracy: 9488/10000 (95%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 1.719172
#
# Test set: Average loss: -3.6223, Accuracy: 9475/10000 (95%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 1.710200
#
# Test set: Average loss: -3.6205, Accuracy: 9491/10000 (95%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 1.683442
#
# Test set: Average loss: -3.6517, Accuracy: 9477/10000 (95%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 1.628696
#
# Test set: Average loss: -3.6327, Accuracy: 9471/10000 (95%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 1.658294
#
# Test set: Average loss: -3.6078, Accuracy: 9459/10000 (95%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 1.646168
#
# Test set: Average loss: -3.6622, Accuracy: 9460/10000 (95%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 1.587139
#
# Test set: Average loss: -3.6874, Accuracy: 9432/10000 (94%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 1.668354
#
# Test set: Average loss: -3.6566, Accuracy: 9424/10000 (94%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 1.656188
#
# Test set: Average loss: -3.7130, Accuracy: 9413/10000 (94%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 1.649263
#
# Test set: Average loss: -3.7940, Accuracy: 9409/10000 (94%)
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 1.628429
#
# Test set: Average loss: -3.6869, Accuracy: 9379/10000 (94%)
#
# Train Epoch: 31 [0/60000 (0%)]	Loss: 1.685354
#
# Test set: Average loss: -3.6678, Accuracy: 9367/10000 (94%)
#
# Train Epoch: 32 [0/60000 (0%)]	Loss: 1.574996
#
# Test set: Average loss: -3.8909, Accuracy: 9340/10000 (93%)
#
# Train Epoch: 33 [0/60000 (0%)]	Loss: 1.694924
#
# Test set: Average loss: -3.8865, Accuracy: 9323/10000 (93%)
#
# Train Epoch: 34 [0/60000 (0%)]	Loss: 1.631033
#
# Test set: Average loss: -3.8565, Accuracy: 9296/10000 (93%)
#
# Train Epoch: 35 [0/60000 (0%)]	Loss: 1.590617
#
# Test set: Average loss: -3.7019, Accuracy: 9233/10000 (92%)
#
# Train Epoch: 36 [0/60000 (0%)]	Loss: 1.563654
#
# Test set: Average loss: -3.7823, Accuracy: 9212/10000 (92%)
#
# Train Epoch: 37 [0/60000 (0%)]	Loss: 1.575861
#
# Test set: Average loss: -3.9506, Accuracy: 9240/10000 (92%)
#
# Train Epoch: 38 [0/60000 (0%)]	Loss: 1.499555
#
# Test set: Average loss: -3.7512, Accuracy: 9128/10000 (91%)
#
# Train Epoch: 39 [0/60000 (0%)]	Loss: 1.573666
#
# Test set: Average loss: -3.9779, Accuracy: 9155/10000 (92%)
#
# Train Epoch: 40 [0/60000 (0%)]	Loss: 1.546047
#
# Test set: Average loss: -3.8672, Accuracy: 9090/10000 (91%)
#
# Train Epoch: 41 [0/60000 (0%)]	Loss: 1.552424
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-72f669ce3237> in <module>()
#       1 torch.cuda.set_device(0)#eps=8.5
#       2 sys.argv = ['-f']
# ----> 3 main()
#
# <ipython-input-15-a80d8b1a685b> in main()
#     145 #             loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=5))
#     146         #loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=9.3))
# --> 147         l1=train(args, cnn1, device, train_loader, optimizer, epoch,eps=8.5)
#     148         loss.append(l1)
#     149
#
# <ipython-input-2-91eba868756c> in train(args, model, device, train_loader, optimizer, epoch, eps)
#       3    # for batch_idx, (data, target, idx, is_pure, is_corrupt) in enumerate(train_loader):
#       4     for batch_idx, (data, target,index) in enumerate(train_loader):
# ----> 5         data, target = data.to(device), target.to(device)
#       6         optimizer.zero_grad()
#       7         output = model(data)
#
# KeyboardInterrupt:

# %%
torch.cuda.set_device(0)#eps=8.0
sys.argv = ['-f']
main()
# Out:
# 9 10
# 60000
# Actual noise 0.50
# [[0.5        0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.5        0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.5        0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.5        0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.5        0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.5
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.5        0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.5        0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.5        0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.5       ]]
# loading dataset...
# building model...
# <bound method Module.parameters of CNN(
#   (c1): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c7): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1))
#   (c8): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1))
#   (c9): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#   (l_c1): Linear(in_features=128, out_features=11, bias=True)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )>
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.311868
#
# Test set: Average loss: -1.3162, Accuracy: 9098/10000 (91%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.907664
#
# Test set: Average loss: -1.7087, Accuracy: 9605/10000 (96%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 1.813558
#
# Test set: Average loss: -1.8244, Accuracy: 9730/10000 (97%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 1.809353
#
# Test set: Average loss: -1.9256, Accuracy: 9769/10000 (98%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 1.757118
#
# Test set: Average loss: -2.0801, Accuracy: 9814/10000 (98%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 1.761031
#
# Test set: Average loss: -2.2830, Accuracy: 9823/10000 (98%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 1.682669
#
# Test set: Average loss: -2.4686, Accuracy: 9845/10000 (98%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 1.775358
#
# Test set: Average loss: -2.6587, Accuracy: 9852/10000 (99%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 1.729329
#
# Test set: Average loss: -2.8133, Accuracy: 9851/10000 (99%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 1.658451
#
# Test set: Average loss: -2.9007, Accuracy: 9858/10000 (99%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 1.723914
#
# Test set: Average loss: -3.0025, Accuracy: 9870/10000 (99%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 1.747478
#
# Test set: Average loss: -3.1541, Accuracy: 9870/10000 (99%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 1.707909
#
# Test set: Average loss: -3.2166, Accuracy: 9885/10000 (99%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 1.680618
#
# Test set: Average loss: -3.3161, Accuracy: 9875/10000 (99%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 1.685293
#
# Test set: Average loss: -3.3555, Accuracy: 9874/10000 (99%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 1.670372
#
# Test set: Average loss: -3.4458, Accuracy: 9879/10000 (99%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 1.689563
#
# Test set: Average loss: -3.4708, Accuracy: 9889/10000 (99%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 1.733437
#
# Test set: Average loss: -3.5320, Accuracy: 9887/10000 (99%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 1.689202
#
# Test set: Average loss: -3.6100, Accuracy: 9887/10000 (99%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 1.680216
#
# Test set: Average loss: -3.6476, Accuracy: 9897/10000 (99%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 1.688731
#
# Test set: Average loss: -3.6665, Accuracy: 9892/10000 (99%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 1.651154
#
# Test set: Average loss: -3.7840, Accuracy: 9893/10000 (99%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 1.646208
#
# Test set: Average loss: -3.7571, Accuracy: 9878/10000 (99%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 1.674024
#
# Test set: Average loss: -3.7192, Accuracy: 9892/10000 (99%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 1.673298
#
# Test set: Average loss: -3.8390, Accuracy: 9888/10000 (99%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 1.629586
#
# Test set: Average loss: -3.8401, Accuracy: 9891/10000 (99%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 1.672750
#
# Test set: Average loss: -3.9155, Accuracy: 9891/10000 (99%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 1.645916
#
# Test set: Average loss: -3.9479, Accuracy: 9885/10000 (99%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 1.639309
#
# Test set: Average loss: -3.8737, Accuracy: 9869/10000 (99%)
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 1.669486
#
# Test set: Average loss: -3.9369, Accuracy: 9891/10000 (99%)
#
# Train Epoch: 31 [0/60000 (0%)]	Loss: 1.647993
#
# Test set: Average loss: -3.8948, Accuracy: 9877/10000 (99%)
#
# Train Epoch: 32 [0/60000 (0%)]	Loss: 1.636631
#
# Test set: Average loss: -3.9306, Accuracy: 9868/10000 (99%)
#
# Train Epoch: 33 [0/60000 (0%)]	Loss: 1.678749
#
# Test set: Average loss: -4.0218, Accuracy: 9880/10000 (99%)
#
# Train Epoch: 34 [0/60000 (0%)]	Loss: 1.614789
#
# Test set: Average loss: -4.0705, Accuracy: 9875/10000 (99%)
#
# Train Epoch: 35 [0/60000 (0%)]	Loss: 1.653522
#
# Test set: Average loss: -3.8787, Accuracy: 9865/10000 (99%)
#
# Train Epoch: 36 [0/60000 (0%)]	Loss: 1.628886
#
# Test set: Average loss: -3.8296, Accuracy: 9857/10000 (99%)
#
# Train Epoch: 37 [0/60000 (0%)]	Loss: 1.591774
#
# Test set: Average loss: -3.9882, Accuracy: 9853/10000 (99%)
#
# Train Epoch: 38 [0/60000 (0%)]	Loss: 1.578753
#
# Test set: Average loss: -4.0980, Accuracy: 9842/10000 (98%)
#
# Train Epoch: 39 [0/60000 (0%)]	Loss: 1.617341
#
# Test set: Average loss: -4.0672, Accuracy: 9824/10000 (98%)
#
# Train Epoch: 40 [0/60000 (0%)]	Loss: 1.628010
#
# Test set: Average loss: -4.0092, Accuracy: 9818/10000 (98%)
#
# Train Epoch: 41 [0/60000 (0%)]	Loss: 1.596649
#
# Test set: Average loss: -4.1426, Accuracy: 9822/10000 (98%)
#
# Train Epoch: 42 [0/60000 (0%)]	Loss: 1.633560
#
# Test set: Average loss: -4.1274, Accuracy: 9795/10000 (98%)
#
# Train Epoch: 43 [0/60000 (0%)]	Loss: 1.620099
#
# Test set: Average loss: -4.0700, Accuracy: 9760/10000 (98%)
#
# Train Epoch: 44 [0/60000 (0%)]	Loss: 1.558250
#
# Test set: Average loss: -3.9196, Accuracy: 9729/10000 (97%)
#
# Train Epoch: 45 [0/60000 (0%)]	Loss: 1.598086
#
# Test set: Average loss: -4.2981, Accuracy: 9768/10000 (98%)
#
# Train Epoch: 46 [0/60000 (0%)]	Loss: 1.572814
#
# Test set: Average loss: -3.9750, Accuracy: 9752/10000 (98%)
#
# Train Epoch: 47 [0/60000 (0%)]	Loss: 1.573893
#
# Test set: Average loss: -4.0394, Accuracy: 9743/10000 (97%)
#
# Train Epoch: 48 [0/60000 (0%)]	Loss: 1.538508
#
# Test set: Average loss: -4.3804, Accuracy: 9735/10000 (97%)
#
# Train Epoch: 49 [0/60000 (0%)]	Loss: 1.536782
#
# Test set: Average loss: -4.1200, Accuracy: 9685/10000 (97%)
#
# Train Epoch: 50 [0/60000 (0%)]	Loss: 1.528605
#
# Test set: Average loss: -4.1408, Accuracy: 9646/10000 (96%)
#
# Train Epoch: 51 [0/60000 (0%)]	Loss: 1.541421
# Test set: Average loss: -4.2712, Accuracy: 9675/10000 (97%)
#
# Train Epoch: 52 [0/60000 (0%)]	Loss: 1.593991
#
# Test set: Average loss: -4.2877, Accuracy: 9683/10000 (97%)
#
# Train Epoch: 53 [0/60000 (0%)]	Loss: 1.553949
#
# Test set: Average loss: -4.0296, Accuracy: 9578/10000 (96%)
#
# Train Epoch: 54 [0/60000 (0%)]	Loss: 1.457996
#
# Test set: Average loss: -4.1761, Accuracy: 9590/10000 (96%)
#
# Train Epoch: 55 [0/60000 (0%)]	Loss: 1.465689
#
# Test set: Average loss: -4.0873, Accuracy: 9496/10000 (95%)
#
# Train Epoch: 56 [0/60000 (0%)]	Loss: 1.510102
#
# Test set: Average loss: -4.1359, Accuracy: 9466/10000 (95%)
#
# Train Epoch: 57 [0/60000 (0%)]	Loss: 1.475302
#
# Test set: Average loss: -4.1878, Accuracy: 9500/10000 (95%)
#
# Train Epoch: 58 [0/60000 (0%)]	Loss: 1.430648
#
# Test set: Average loss: -4.0842, Accuracy: 9394/10000 (94%)
#
# Train Epoch: 59 [0/60000 (0%)]	Loss: 1.424664
#
# Test set: Average loss: -3.9793, Accuracy: 9286/10000 (93%)
#
# Train Epoch: 60 [0/60000 (0%)]	Loss: 1.444014
#
# Test set: Average loss: -4.3580, Accuracy: 9309/10000 (93%)
#
# Train Epoch: 61 [0/60000 (0%)]	Loss: 1.407664
#
# Test set: Average loss: -4.3570, Accuracy: 9353/10000 (94%)
#
# Train Epoch: 62 [0/60000 (0%)]	Loss: 1.360357
#
# Test set: Average loss: -4.2483, Accuracy: 9167/10000 (92%)
#
# Train Epoch: 63 [0/60000 (0%)]	Loss: 1.373627
#
# Test set: Average loss: -4.5201, Accuracy: 9304/10000 (93%)
#
# Train Epoch: 64 [0/60000 (0%)]	Loss: 1.373333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a5401f464a6b> in <module>()
#       1 torch.cuda.set_device(0)#eps=8.0
#       2 sys.argv = ['-f']
# ----> 3 main()
#
# <ipython-input-3-50995cfddc9d> in main()
#     145 #             loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=5))
#     146         #loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=9.3))
# --> 147         l1=train(args, cnn1, device, train_loader, optimizer, epoch,eps=8.0)
#     148         loss.append(l1)
#     149
#
# <ipython-input-2-91eba868756c> in train(args, model, device, train_loader, optimizer, epoch, eps)
#      12         loss = F.nll_loss(output, target)
#      13
# ---> 14         loss.backward()
#      15
#      16         optimizer.step()
#
# ~/anaconda3/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
torch.cuda.set_device(0)#eps=7.5
sys.argv = ['-f']
main()
# Out:
# 9 10
# 60000
# Actual noise 0.50
# [[0.5        0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.5        0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.5        0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.5        0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.5        0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.5
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.5        0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.5        0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.5        0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.5       ]]
# loading dataset...
# building model...
# <bound method Module.parameters of CNN(
#   (c1): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c7): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1))
#   (c8): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1))
#   (c9): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#   (l_c1): Linear(in_features=128, out_features=11, bias=True)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )>
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.305418
#
# Test set: Average loss: -1.2795, Accuracy: 9068/10000 (91%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.903457
#
# Test set: Average loss: -1.7112, Accuracy: 9617/10000 (96%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 1.800474
#
# Test set: Average loss: -1.8493, Accuracy: 9726/10000 (97%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 1.777892
#
# Test set: Average loss: -2.0710, Accuracy: 9771/10000 (98%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 1.714166
#
# Test set: Average loss: -2.3329, Accuracy: 9806/10000 (98%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 1.711280
#
# Test set: Average loss: -2.5554, Accuracy: 9815/10000 (98%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 1.638167
#
# Test set: Average loss: -2.7482, Accuracy: 9835/10000 (98%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 1.728976
#
# Test set: Average loss: -2.9505, Accuracy: 9851/10000 (99%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 1.686082
#
# Test set: Average loss: -3.1000, Accuracy: 9855/10000 (99%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 1.619048
#
# Test set: Average loss: -3.1791, Accuracy: 9851/10000 (99%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 1.683342
#
# Test set: Average loss: -3.2828, Accuracy: 9865/10000 (99%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 1.705704
#
# Test set: Average loss: -3.4433, Accuracy: 9872/10000 (99%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 1.667632
#
# Test set: Average loss: -3.4892, Accuracy: 9899/10000 (99%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 1.644225
#
# Test set: Average loss: -3.5552, Accuracy: 9878/10000 (99%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 1.645635
#
# Test set: Average loss: -3.6217, Accuracy: 9879/10000 (99%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 1.634831
#
# Test set: Average loss: -3.6887, Accuracy: 9881/10000 (99%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 1.650300
#
# Test set: Average loss: -3.7583, Accuracy: 9891/10000 (99%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 1.692927
#
# Test set: Average loss: -3.7542, Accuracy: 9883/10000 (99%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 1.651604
#
# Test set: Average loss: -3.8982, Accuracy: 9895/10000 (99%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 1.643531
#
# Test set: Average loss: -3.9019, Accuracy: 9888/10000 (99%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 1.649629
#
# Test set: Average loss: -3.9257, Accuracy: 9886/10000 (99%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 1.616491
#
# Test set: Average loss: -3.9720, Accuracy: 9889/10000 (99%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 1.612558
#
# Test set: Average loss: -4.0233, Accuracy: 9886/10000 (99%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 1.637890
#
# Test set: Average loss: -3.9910, Accuracy: 9889/10000 (99%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 1.640144
#
# Test set: Average loss: -4.1440, Accuracy: 9892/10000 (99%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 1.592051
#
# Test set: Average loss: -4.1550, Accuracy: 9897/10000 (99%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 1.642229
#
# Test set: Average loss: -4.1497, Accuracy: 9878/10000 (99%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 1.609005
#
# Test set: Average loss: -4.2254, Accuracy: 9888/10000 (99%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 1.604750
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-10d2e7bf09d0> in <module>()
#       1 torch.cuda.set_device(0)#eps=7.5
#       2 sys.argv = ['-f']
# ----> 3 main()
#
# <ipython-input-5-4465afd30962> in main()
#     145 #             loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=5))
#     146         #loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=9.3))
# --> 147         l1=train(args, cnn1, device, train_loader, optimizer, epoch,eps=7.5)
#     148         loss.append(l1)
#     149
#
# <ipython-input-2-91eba868756c> in train(args, model, device, train_loader, optimizer, epoch, eps)
#       3    # for batch_idx, (data, target, idx, is_pure, is_corrupt) in enumerate(train_loader):
#       4     for batch_idx, (data, target,index) in enumerate(train_loader):
# ----> 5         data, target = data.to(device), target.to(device)
#       6         optimizer.zero_grad()
#       7         output = model(data)
#
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/ziyinl/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe

# %%
torch.cuda.set_device(0)#eps=7.5
sys.argv = ['-f']
main()
# Out:
# 9 10
# 60000
# Actual noise 0.50
# [[0.5        0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.5        0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.5        0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.5        0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.5        0.05555556
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.5
#   0.05555556 0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.5        0.05555556 0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.5        0.05555556 0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.5        0.05555556]
#  [0.05555556 0.05555556 0.05555556 0.05555556 0.05555556 0.05555556
#   0.05555556 0.05555556 0.05555556 0.5       ]]
# loading dataset...
# building model...
# <bound method Module.parameters of CNN(
#   (c1): Conv2d(1, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c7): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1))
#   (c8): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1))
#   (c9): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#   (l_c1): Linear(in_features=128, out_features=11, bias=True)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )>
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.305418
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-10d2e7bf09d0> in <module>()
#       1 torch.cuda.set_device(0)#eps=7.5
#       2 sys.argv = ['-f']
# ----> 3 main()
#
# <ipython-input-5-4465afd30962> in main()
#     145 #             loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=5))
#     146         #loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=9.3))
# --> 147         l1=train(args, cnn1, device, train_loader, optimizer, epoch,eps=7.5)
#     148         loss.append(l1)
#     149
#
# <ipython-input-4-91eba868756c> in train(args, model, device, train_loader, optimizer, epoch, eps)
#       3    # for batch_idx, (data, target, idx, is_pure, is_corrupt) in enumerate(train_loader):
#       4     for batch_idx, (data, target,index) in enumerate(train_loader):
# ----> 5         data, target = data.to(device), target.to(device)
#       6         optimizer.zero_grad()
#       7         output = model(data)
#
# KeyboardInterrupt:
