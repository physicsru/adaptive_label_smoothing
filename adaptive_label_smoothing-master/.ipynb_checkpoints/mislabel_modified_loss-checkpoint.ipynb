# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from net_new import Net
import random
import sys
import numpy as np
from torchvision import datasets, transforms
from torch.utils.data import Dataset, DataLoader

# %%
import sys
print(sys.executable)
# Out:
# /home/zliu/anaconda3/envs/myenv/bin/python

# %%
class MyDataset(Dataset):
    def __init__(self,rate):
        self.mnist = datasets.MNIST('../data', train=True, download=True,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))]))
        self.ran=[i for i in range(0,60000)]
        random.seed(42)
        torch.manual_seed(0)
        self.index=random.sample(self.ran,int(60000*rate))
        self.index_yes=list(set(range(60000))-set(self.index))
        self.mnist.train_labels[self.index]=self.mnist.train_labels[self.index].random_(0,10)
        
    def __getitem__(self, index):
        data, target = self.mnist[index]
        is_pure = index in self.index_yes
        is_corrupt = index in self.index
        return data, target, index, is_pure, is_corrupt

    def __len__(self):
        return len(self.mnist)

# %%
import copy

# %%
def train(args, model, device, train_loader, optimizer, epoch, eps=9.9):
    model.train()
    for batch_idx, (data, target, idx, is_pure, is_corrupt) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        output2 = output[:,:10]
        output2 = F.log_softmax(output2, dim=1)
        output = F.softmax(output, dim=1)
        output = output + (output[:, 10] / eps).unsqueeze(1)
        output.log_()
        
        loss_pure = F.nll_loss(output[is_pure],target[is_pure])
        loss_corrupt = F.nll_loss(output[is_corrupt],target[is_corrupt])
        loss = F.nll_loss(output, target)
        
        loss.backward()
        
        optimizer.step()
        loss2=F.nll_loss(output2,target)
        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    return loss.item(), loss_pure.item(), loss_corrupt.item()

def test(args, model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    acc = []
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output[:,:10].argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    acc=100. * correct / len(test_loader.dataset);
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        acc))
    return acc

# %%
x=datasets.MNIST('../data', train=True, download=True,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))]))

# %%
x.train_labels
# Out:
# /home/zliu/anaconda3/envs/myenv/lib/python3.6/site-packages/torchvision/datasets/mnist.py:43: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# tensor([5, 0, 4,  ..., 5, 6, 8])

# %%
ran=[i for i in range(0,60000)]
random.seed(42)
torch.manual_seed(0)
index=random.sample(ran,int(60000*0.8))

# %%
#index_yes=[x for x in range(60000) if x not in index]
index_yes = set(range(60000))-set(index)

# %%
x_origin=copy.deepcopy(x.train_labels.numpy())

# %%
x.train_labels[index]=x.train_labels[index].random_(0,10)
x.train_labels
# Out:
# tensor([2, 5, 0,  ..., 5, 6, 5])

# %%
(x_origin==x.train_labels.numpy()).sum()
# Out:
# 16800

# %%
x_corrupt=[x[i] for i in index]

# %%
x_pure=[x[i] for i in index_yes]

# %%
# Out:
# 48000 12000

# %%
def main():
    # Training settings
    parser = argparse.ArgumentParser(description='PyTorch MNIST Example')
    parser.add_argument('--batch-size', type=int, default=600, metavar='N',
                        help='input batch size for training (default: 256)')
    parser.add_argument('--test-batch-size', type=int, default=4000, metavar='N',
                        help='input batch size for testing (default: 1000)')
    parser.add_argument('--epochs', type=int, default=100, metavar='N',
                        help='number of epochs to train (default: 10)')
    parser.add_argument('--lr', type=float, default=0.005, metavar='LR',
                        help='learning rate (default: 0.01)')
    parser.add_argument('--momentum', type=float, default=0.9, metavar='M',
                        help='SGD momentum (default: 0.5)')
    parser.add_argument('--no-cuda', action='store_true', default=False,
                        help='disables CUDA training')
    parser.add_argument('--seed', type=int, default=1, metavar='S',
                        help='random seed (default: 1)')
    parser.add_argument('--log-interval', type=int, default=100, metavar='N',
                        help='how many batches to wait before logging training status')
    
    parser.add_argument('--save-model', action='store_true', default=False,
                        help='For Saving the current Model')
    args = parser.parse_args()
    use_cuda = not args.no_cuda and torch.cuda.is_available()

    torch.manual_seed(args.seed)

    device = torch.device("cuda" if use_cuda else "cpu")
     
    kwargs = {'num_workers': 4, 'pin_memory': True} if use_cuda else {}
#     train_loader = torch.utils.data.DataLoader(
#         x,
#         batch_size=args.batch_size, shuffle=True, **kwargs)
    test_loader = torch.utils.data.DataLoader(
        datasets.MNIST('../data', train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ])),
        batch_size=args.test_batch_size, shuffle=True, **kwargs)
#     train_loader=x
    dataset = MyDataset(0.5)
    loader = DataLoader(dataset,
                        batch_size=600,
                        shuffle=True,
                        num_workers=10)
    model = Net().to(device)
    optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)

    acc=[]
    loss=[]
    loss_pure=[]
    loss_corrupt=[]
    for epoch in range(1, args.epochs + 1):
#         if epoch<20:
#             loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=9.5))
#         else:
#             loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=5))
        #loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=9.3))
        l1,l2,l3=train(args, model, device, loader, optimizer, epoch,eps=9.3)
        loss.append(l1)
        loss_pure.append(l2)
        loss_corrupt.append(l3)
        acc.append(test(args, model, device, test_loader))
#     np.save("acc1.npy",acc)
#     np.save("loss1.npy",loss)
#     np.save("loss_pure1.npy",loss_pure)
#     np.save("loss_corrupt1.npy",loss_corrupt)
#     if (args.save_model):
#         torch.save(model.state_dict(),"mnist_cnn1.pt")

# %%
torch.cuda.set_device(1)
sys.argv = ['-f']
main()
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.296890
#
# Test set: Average loss: -2.0060, Accuracy: 8813/10000 (88%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.885533

# %%
torch.cuda.set_device(1) # 80%mislable with 9.3 eps
sys.argv = ['-f']
main()
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.295446
#
# Test set: Average loss: -0.1693, Accuracy: 5953/10000 (60%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 2.249107
#
# Test set: Average loss: -0.5894, Accuracy: 6368/10000 (64%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 2.210102
#
# Test set: Average loss: -1.3385, Accuracy: 8142/10000 (81%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 2.161174
#
# Test set: Average loss: -1.8716, Accuracy: 8570/10000 (86%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 2.172600
#
# Test set: Average loss: -2.2490, Accuracy: 8741/10000 (87%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 2.155076
#
# Test set: Average loss: -2.5129, Accuracy: 8935/10000 (89%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 2.128894
#
# Test set: Average loss: -2.7142, Accuracy: 8981/10000 (90%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 2.125039
#
# Test set: Average loss: -2.8240, Accuracy: 9022/10000 (90%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 2.152467
#
# Test set: Average loss: -2.9399, Accuracy: 9135/10000 (91%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 2.156647
#
# Test set: Average loss: -3.0917, Accuracy: 9149/10000 (91%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 2.145738
#
# Test set: Average loss: -3.1618, Accuracy: 9144/10000 (91%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 2.131698
#
# Test set: Average loss: -3.2410, Accuracy: 9247/10000 (92%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 2.114257
#
# Test set: Average loss: -3.3510, Accuracy: 9274/10000 (93%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 2.105835
#
# Test set: Average loss: -3.4410, Accuracy: 9327/10000 (93%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 2.154448
#
# Test set: Average loss: -3.4293, Accuracy: 9323/10000 (93%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 2.120562
#
# Test set: Average loss: -3.4945, Accuracy: 9346/10000 (93%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 2.104448
#
# Test set: Average loss: -3.5972, Accuracy: 9378/10000 (94%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 2.146988
#
# Test set: Average loss: -3.6570, Accuracy: 9393/10000 (94%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 2.129898
#
# Test set: Average loss: -3.7298, Accuracy: 9415/10000 (94%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 2.118441
#
# Test set: Average loss: -3.7617, Accuracy: 9449/10000 (94%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 2.160398
#
# Test set: Average loss: -3.8433, Accuracy: 9455/10000 (95%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 2.102088
#
# Test set: Average loss: -3.8766, Accuracy: 9491/10000 (95%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 2.148724
#
# Test set: Average loss: -3.9600, Accuracy: 9464/10000 (95%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 2.125648
#
# Test set: Average loss: -4.0283, Accuracy: 9495/10000 (95%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 2.156440
#
# Test set: Average loss: -4.0679, Accuracy: 9511/10000 (95%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 2.111588
#
# Test set: Average loss: -4.1652, Accuracy: 9532/10000 (95%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 2.117488
#
# Test set: Average loss: -4.1041, Accuracy: 9538/10000 (95%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 2.087556
#
# Test set: Average loss: -4.1970, Accuracy: 9545/10000 (95%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 2.114266
#
# Test set: Average loss: -4.2724, Accuracy: 9546/10000 (95%)
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 2.101142
#
# Test set: Average loss: -4.2969, Accuracy: 9557/10000 (96%)
#
# Train Epoch: 31 [0/60000 (0%)]	Loss: 2.135868
#
# Test set: Average loss: -4.2829, Accuracy: 9569/10000 (96%)
#
# Train Epoch: 32 [0/60000 (0%)]	Loss: 2.158873
#
# Test set: Average loss: -4.4141, Accuracy: 9571/10000 (96%)
#
# Train Epoch: 33 [0/60000 (0%)]	Loss: 2.111677
#
# Test set: Average loss: -4.4799, Accuracy: 9551/10000 (96%)
#
# Train Epoch: 34 [0/60000 (0%)]	Loss: 2.107431
#
# Test set: Average loss: -4.5026, Accuracy: 9564/10000 (96%)
#
# Train Epoch: 35 [0/60000 (0%)]	Loss: 2.104071
#
# Test set: Average loss: -4.3414, Accuracy: 9553/10000 (96%)
#
# Train Epoch: 36 [0/60000 (0%)]	Loss: 2.151407
#
# Test set: Average loss: -4.5434, Accuracy: 9553/10000 (96%)
#
# Train Epoch: 37 [0/60000 (0%)]	Loss: 2.139539
#
# Test set: Average loss: -4.5150, Accuracy: 9604/10000 (96%)
#
# Train Epoch: 38 [0/60000 (0%)]	Loss: 2.110721
#
# Test set: Average loss: -4.5478, Accuracy: 9611/10000 (96%)
#
# Train Epoch: 39 [0/60000 (0%)]	Loss: 2.120509
#
# Test set: Average loss: -4.6884, Accuracy: 9585/10000 (96%)
#
# Train Epoch: 40 [0/60000 (0%)]	Loss: 2.121346
#
# Test set: Average loss: -4.6009, Accuracy: 9588/10000 (96%)
#
# Train Epoch: 41 [0/60000 (0%)]	Loss: 2.141756
#
# Test set: Average loss: -4.6992, Accuracy: 9580/10000 (96%)
#
# Train Epoch: 42 [0/60000 (0%)]	Loss: 2.114948
#
# Test set: Average loss: -4.7156, Accuracy: 9590/10000 (96%)
#
# Train Epoch: 43 [0/60000 (0%)]	Loss: 2.113876
#
# Test set: Average loss: -4.7797, Accuracy: 9576/10000 (96%)
#
# Train Epoch: 44 [0/60000 (0%)]	Loss: 2.114216
#
# Test set: Average loss: -4.6358, Accuracy: 9609/10000 (96%)
#
# Train Epoch: 45 [0/60000 (0%)]	Loss: 2.099967
#
# Test set: Average loss: -4.8485, Accuracy: 9612/10000 (96%)
#
# Train Epoch: 46 [0/60000 (0%)]	Loss: 2.088318
#
# Test set: Average loss: -4.8075, Accuracy: 9603/10000 (96%)
#
# Train Epoch: 47 [0/60000 (0%)]	Loss: 2.141298
#
# Test set: Average loss: -4.7122, Accuracy: 9623/10000 (96%)
#
# Train Epoch: 48 [0/60000 (0%)]	Loss: 2.106879
#
# Test set: Average loss: -4.8524, Accuracy: 9601/10000 (96%)
#
# Train Epoch: 49 [0/60000 (0%)]	Loss: 2.127360
#
# Test set: Average loss: -4.8694, Accuracy: 9612/10000 (96%)
#
# Train Epoch: 50 [0/60000 (0%)]	Loss: 2.115415
#
# Test set: Average loss: -4.9396, Accuracy: 9627/10000 (96%)
#
# Train Epoch: 51 [0/60000 (0%)]	Loss: 2.151232
#
# Test set: Average loss: -4.9194, Accuracy: 9626/10000 (96%)
#
# Train Epoch: 52 [0/60000 (0%)]	Loss: 2.098854
#
# Test set: Average loss: -4.9755, Accuracy: 9625/10000 (96%)
#
# Train Epoch: 53 [0/60000 (0%)]	Loss: 2.090171
#
# Test set: Average loss: -4.9917, Accuracy: 9637/10000 (96%)
#
# Train Epoch: 54 [0/60000 (0%)]	Loss: 2.079066
#
# Test set: Average loss: -4.9944, Accuracy: 9610/10000 (96%)
#
# Train Epoch: 55 [0/60000 (0%)]	Loss: 2.117670
#
# Test set: Average loss: -5.0072, Accuracy: 9619/10000 (96%)
#
# Train Epoch: 56 [0/60000 (0%)]	Loss: 2.116253
#
# Test set: Average loss: -5.0299, Accuracy: 9626/10000 (96%)
#
# Train Epoch: 57 [0/60000 (0%)]	Loss: 2.131053
#
# Test set: Average loss: -5.0889, Accuracy: 9644/10000 (96%)
#
# Train Epoch: 58 [0/60000 (0%)]	Loss: 2.093545
#
# Test set: Average loss: -5.0914, Accuracy: 9579/10000 (96%)
#
# Train Epoch: 59 [0/60000 (0%)]	Loss: 2.072623
#
# Test set: Average loss: -5.0817, Accuracy: 9642/10000 (96%)
#
# Train Epoch: 60 [0/60000 (0%)]	Loss: 2.108015
#
# Test set: Average loss: -5.2195, Accuracy: 9621/10000 (96%)
#
# Train Epoch: 61 [0/60000 (0%)]	Loss: 2.102693
#
# Test set: Average loss: -4.9714, Accuracy: 9620/10000 (96%)
#
# Train Epoch: 62 [0/60000 (0%)]	Loss: 2.102502
#
# Test set: Average loss: -5.1354, Accuracy: 9623/10000 (96%)
#
# Train Epoch: 63 [0/60000 (0%)]	Loss: 2.092749
#
# Test set: Average loss: -5.1138, Accuracy: 9645/10000 (96%)
#
# Train Epoch: 64 [0/60000 (0%)]	Loss: 2.158953
#
# Test set: Average loss: -5.1476, Accuracy: 9630/10000 (96%)
#
# Train Epoch: 65 [0/60000 (0%)]	Loss: 2.107595
#
# Test set: Average loss: -5.2909, Accuracy: 9619/10000 (96%)
#
# Train Epoch: 66 [0/60000 (0%)]	Loss: 2.118910
#
# Test set: Average loss: -5.0403, Accuracy: 9643/10000 (96%)
#
# Train Epoch: 67 [0/60000 (0%)]	Loss: 2.118655
#
# Test set: Average loss: -5.2402, Accuracy: 9644/10000 (96%)
#
# Train Epoch: 68 [0/60000 (0%)]	Loss: 2.068946
#
# Test set: Average loss: -5.2924, Accuracy: 9620/10000 (96%)
#
# Train Epoch: 69 [0/60000 (0%)]	Loss: 2.073452
#
# Test set: Average loss: -5.3260, Accuracy: 9648/10000 (96%)
#
# Train Epoch: 70 [0/60000 (0%)]	Loss: 2.046035
#
# Test set: Average loss: -5.2245, Accuracy: 9635/10000 (96%)
#
# Train Epoch: 71 [0/60000 (0%)]	Loss: 2.091016
#
# Test set: Average loss: -5.2629, Accuracy: 9637/10000 (96%)
#
# Train Epoch: 72 [0/60000 (0%)]	Loss: 2.052831
#
# Test set: Average loss: -5.4182, Accuracy: 9641/10000 (96%)
#
# Train Epoch: 73 [0/60000 (0%)]	Loss: 2.084931
#
# Test set: Average loss: -5.3016, Accuracy: 9644/10000 (96%)
#
# Train Epoch: 74 [0/60000 (0%)]	Loss: 2.036390
#
# Test set: Average loss: -5.2788, Accuracy: 9625/10000 (96%)
#
# Train Epoch: 75 [0/60000 (0%)]	Loss: 2.042894
#
# Test set: Average loss: -5.3943, Accuracy: 9613/10000 (96%)
#
# Train Epoch: 76 [0/60000 (0%)]	Loss: 2.055905
#
# Test set: Average loss: -5.3267, Accuracy: 9651/10000 (97%)
# Train Epoch: 77 [0/60000 (0%)]	Loss: 2.098234
#
# Test set: Average loss: -5.3569, Accuracy: 9618/10000 (96%)
#
# Train Epoch: 78 [0/60000 (0%)]	Loss: 2.080163
#
# Test set: Average loss: -5.2312, Accuracy: 9609/10000 (96%)
#
# Train Epoch: 79 [0/60000 (0%)]	Loss: 2.050334
#
# Test set: Average loss: -5.2082, Accuracy: 9593/10000 (96%)
#
# Train Epoch: 80 [0/60000 (0%)]	Loss: 2.045109
#
# Test set: Average loss: -5.5108, Accuracy: 9601/10000 (96%)
#
# Train Epoch: 81 [0/60000 (0%)]	Loss: 2.055662
#
# Test set: Average loss: -5.5404, Accuracy: 9624/10000 (96%)
#
# Train Epoch: 82 [0/60000 (0%)]	Loss: 2.102873
#
# Test set: Average loss: -5.5955, Accuracy: 9632/10000 (96%)
#
# Train Epoch: 83 [0/60000 (0%)]	Loss: 2.042563
#
# Test set: Average loss: -5.4876, Accuracy: 9604/10000 (96%)
#
# Train Epoch: 84 [0/60000 (0%)]	Loss: 2.071163
#
# Test set: Average loss: -5.5121, Accuracy: 9584/10000 (96%)
#
# Train Epoch: 85 [0/60000 (0%)]	Loss: 2.031580
#
# Test set: Average loss: -5.5516, Accuracy: 9594/10000 (96%)
#
# Train Epoch: 86 [0/60000 (0%)]	Loss: 2.095311
#
# Test set: Average loss: -5.4204, Accuracy: 9583/10000 (96%)
#
# Train Epoch: 87 [0/60000 (0%)]	Loss: 2.107213
#
# Test set: Average loss: -5.6244, Accuracy: 9586/10000 (96%)
#
# Train Epoch: 88 [0/60000 (0%)]	Loss: 2.056172
#
# Test set: Average loss: -5.3771, Accuracy: 9592/10000 (96%)
#
# Train Epoch: 89 [0/60000 (0%)]	Loss: 2.049230
#
# Test set: Average loss: -5.5109, Accuracy: 9601/10000 (96%)
#
# Train Epoch: 90 [0/60000 (0%)]	Loss: 2.090485
#
# Test set: Average loss: -5.5088, Accuracy: 9603/10000 (96%)
#
# Train Epoch: 91 [0/60000 (0%)]	Loss: 2.058820
#
# Test set: Average loss: -5.4922, Accuracy: 9606/10000 (96%)
#
# Train Epoch: 92 [0/60000 (0%)]	Loss: 2.059446
#
# Test set: Average loss: -5.6052, Accuracy: 9580/10000 (96%)
#
# Train Epoch: 93 [0/60000 (0%)]	Loss: 2.021712
#
# Test set: Average loss: -5.6940, Accuracy: 9591/10000 (96%)
#
# Train Epoch: 94 [0/60000 (0%)]	Loss: 2.074537
#
# Test set: Average loss: -5.6999, Accuracy: 9595/10000 (96%)
#
# Train Epoch: 95 [0/60000 (0%)]	Loss: 2.083073
#
# Test set: Average loss: -5.7975, Accuracy: 9528/10000 (95%)
#
# Train Epoch: 96 [0/60000 (0%)]	Loss: 2.066734
#
# Test set: Average loss: -5.7056, Accuracy: 9541/10000 (95%)
#
# Train Epoch: 97 [0/60000 (0%)]	Loss: 2.054375
#
# Test set: Average loss: -5.7586, Accuracy: 9550/10000 (96%)
#
# Train Epoch: 98 [0/60000 (0%)]	Loss: 2.061616
#
# Test set: Average loss: -5.9903, Accuracy: 9571/10000 (96%)
#
# Train Epoch: 99 [0/60000 (0%)]	Loss: 2.012053
#
# Test set: Average loss: -5.8873, Accuracy: 9541/10000 (95%)
#
# Train Epoch: 100 [0/60000 (0%)]	Loss: 2.023791
#
# Test set: Average loss: -5.8753, Accuracy: 9545/10000 (95%)

# %%
sys.argv = ['-f']
main()
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.307533
#
# Test set: Average loss: 2.0278, Accuracy: 6950/10000 (70%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 2.256609
#
# Test set: Average loss: 1.7520, Accuracy: 8173/10000 (82%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 2.238003
#
# Test set: Average loss: 1.6591, Accuracy: 8583/10000 (86%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 2.212297
#
# Test set: Average loss: 1.6162, Accuracy: 8995/10000 (90%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 2.211491
#
# Test set: Average loss: 1.5733, Accuracy: 9166/10000 (92%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 2.199877
#
# Test set: Average loss: 1.5431, Accuracy: 9223/10000 (92%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 2.211110
#
# Test set: Average loss: 1.5427, Accuracy: 9236/10000 (92%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 2.221525
#
# Test set: Average loss: 1.5187, Accuracy: 9357/10000 (94%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 2.215821
#
# Test set: Average loss: 1.5301, Accuracy: 9373/10000 (94%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 2.205967
#
# Test set: Average loss: 1.4781, Accuracy: 9373/10000 (94%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 2.179498
#
# Test set: Average loss: 1.4700, Accuracy: 9434/10000 (94%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 2.170424
#
# Test set: Average loss: 1.4429, Accuracy: 9484/10000 (95%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 2.197846
#
# Test set: Average loss: 1.4409, Accuracy: 9513/10000 (95%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 2.155816
#
# Test set: Average loss: 1.4731, Accuracy: 9510/10000 (95%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 2.172687
#
# Test set: Average loss: 1.4353, Accuracy: 9495/10000 (95%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 2.190565
#
# Test set: Average loss: 1.4374, Accuracy: 9553/10000 (96%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 2.194126
#
# Test set: Average loss: 1.4238, Accuracy: 9545/10000 (95%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 2.143028
#
# Test set: Average loss: 1.4320, Accuracy: 9597/10000 (96%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 2.143031
#
# Test set: Average loss: 1.3997, Accuracy: 9544/10000 (95%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 2.133925
#
# Test set: Average loss: 1.4229, Accuracy: 9597/10000 (96%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 2.194737
#
# Test set: Average loss: 1.4107, Accuracy: 9604/10000 (96%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 2.214005
#
# Test set: Average loss: 1.4095, Accuracy: 9620/10000 (96%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 2.162200
#
# Test set: Average loss: 1.3640, Accuracy: 9601/10000 (96%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 2.226125
#
# Test set: Average loss: 1.4088, Accuracy: 9590/10000 (96%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 2.130870
#
# Test set: Average loss: 1.4161, Accuracy: 9611/10000 (96%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 2.150799
#
# Test set: Average loss: 1.3834, Accuracy: 9539/10000 (95%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 2.170751
#
# Test set: Average loss: 1.3516, Accuracy: 9521/10000 (95%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 2.118911
#
# Test set: Average loss: 1.3745, Accuracy: 9610/10000 (96%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 2.151388
#
# Test set: Average loss: 1.3386, Accuracy: 9605/10000 (96%)
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 2.145905
#
# Test set: Average loss: 1.3909, Accuracy: 9504/10000 (95%)
#
# Train Epoch: 31 [0/60000 (0%)]	Loss: 2.145026
#
# Test set: Average loss: 1.3930, Accuracy: 9557/10000 (96%)
#
# Train Epoch: 32 [0/60000 (0%)]	Loss: 2.196693
#
# Test set: Average loss: 1.4426, Accuracy: 9490/10000 (95%)
#
# Train Epoch: 33 [0/60000 (0%)]	Loss: 2.126752
#
# Test set: Average loss: 1.3647, Accuracy: 9409/10000 (94%)
#
# Train Epoch: 34 [0/60000 (0%)]	Loss: 2.161182
#
# Test set: Average loss: 1.4175, Accuracy: 9554/10000 (96%)
#
# Train Epoch: 35 [0/60000 (0%)]	Loss: 2.129464
#
# Test set: Average loss: 1.3901, Accuracy: 9450/10000 (94%)
#
# Train Epoch: 36 [0/60000 (0%)]	Loss: 2.168315
#
# Test set: Average loss: 1.3391, Accuracy: 9532/10000 (95%)
#
# Train Epoch: 37 [0/60000 (0%)]	Loss: 2.116545
#
# Test set: Average loss: 1.3815, Accuracy: 9467/10000 (95%)
#
# Train Epoch: 38 [0/60000 (0%)]	Loss: 2.154542
#
# Test set: Average loss: 1.3638, Accuracy: 9518/10000 (95%)
#
# Train Epoch: 39 [0/60000 (0%)]	Loss: 2.079606
#
# Test set: Average loss: 1.3317, Accuracy: 9422/10000 (94%)
#
# Train Epoch: 40 [0/60000 (0%)]	Loss: 2.138405
#
# Test set: Average loss: 1.3546, Accuracy: 9411/10000 (94%)
#
# Train Epoch: 41 [0/60000 (0%)]	Loss: 2.086497
#
# Test set: Average loss: 1.3020, Accuracy: 9370/10000 (94%)
#
# Train Epoch: 42 [0/60000 (0%)]	Loss: 2.113138
#
# Test set: Average loss: 1.3530, Accuracy: 9380/10000 (94%)
#
# Train Epoch: 43 [0/60000 (0%)]	Loss: 2.097365
#
# Test set: Average loss: 1.3731, Accuracy: 9258/10000 (93%)
#
# Train Epoch: 44 [0/60000 (0%)]	Loss: 2.109897
#
# Test set: Average loss: 1.3879, Accuracy: 9239/10000 (92%)
#
# Train Epoch: 45 [0/60000 (0%)]	Loss: 2.108228
#
# Test set: Average loss: 1.3299, Accuracy: 9228/10000 (92%)
#
# Train Epoch: 46 [0/60000 (0%)]	Loss: 2.099027
#
# Test set: Average loss: 1.3537, Accuracy: 9032/10000 (90%)
#
# Train Epoch: 47 [0/60000 (0%)]	Loss: 2.068302
#
# Test set: Average loss: 1.3603, Accuracy: 9157/10000 (92%)
#
# Train Epoch: 48 [0/60000 (0%)]	Loss: 2.118988
#
# Test set: Average loss: 1.3405, Accuracy: 8909/10000 (89%)
#
# Train Epoch: 49 [0/60000 (0%)]	Loss: 2.068717
#
# Test set: Average loss: 1.3831, Accuracy: 8915/10000 (89%)
#
# Train Epoch: 50 [0/60000 (0%)]	Loss: 2.044190
#
# Test set: Average loss: 1.4081, Accuracy: 8687/10000 (87%)
#
# Train Epoch: 51 [0/60000 (0%)]	Loss: 2.003108
#
# Test set: Average loss: 1.3600, Accuracy: 8948/10000 (89%)
#
# Train Epoch: 52 [0/60000 (0%)]	Loss: 2.058474
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-9883e1753739> in <module>
#       1 sys.argv = ['-f']
# ----> 2 main()
#
# <ipython-input-51-662433e06967> in main()
#      46     loss=[]
#      47     for epoch in range(1, args.epochs + 1):
# ---> 48         loss.append(train(args, model, device, train_loader, optimizer, epoch, eps=9.9999))
#      49         acc.append(test(args, model, device, test_loader))
#      50     np.save("acc.npy",acc)
#
# <ipython-input-41-d9b630e95fdf> in train(args, model, device, train_loader, optimizer, epoch, eps)
#       1 def train(args, model, device, train_loader, optimizer, epoch, eps=9.9):
#       2     model.train()
# ----> 3     for batch_idx, (data, target) in enumerate(train_loader):
#       4         data, target = data.to(device), target.to(device)
#       5         optimizer.zero_grad()
#
# ~/anaconda3/envs/myenv/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     802
#     803             assert not self.shutdown and self.tasks_outstanding > 0
# --> 804             idx, data = self._get_data()
#     805             self.tasks_outstanding -= 1
#     806
#
# ~/anaconda3/envs/myenv/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#     759         elif self.pin_memory:
#     760             while self.pin_memory_thread.is_alive():
# --> 761                 success, data = self._try_get_data()
#     762                 if success:
#     763                     return data
#
# ~/anaconda3/envs/myenv/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     722         #   (bool: whether successfully get data, any: data if successful else None)
#     723         try:
# --> 724             data = self.data_queue.get(timeout=timeout)
#     725             return (True, data)
#     726         except Exception as e:
#
# ~/anaconda3/envs/myenv/lib/python3.6/queue.py in get(self, block, timeout)
#     171                     if remaining <= 0.0:
#     172                         raise Empty
# --> 173                     self.not_empty.wait(remaining)
#     174             item = self._get()
#     175             self.not_full.notify()
#
# ~/anaconda3/envs/myenv/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
acc=np.load("acc1.npy")
x_axis=np.arange(100)
loss=np.load("loss1.npy")

# %%
import matplotlib.pyplot as plt

# %%
# fig,left_axis=plt.subplots()
# right_axis = left_axis.twinx()

# p1, = left_axis.plot(x_axis,p,color='blue',label="acc")
# p2, = right_axis.plot(x_axis,loss,color='red',label="loss")
# plt.title("result")
# plt.legend(loc="best")
fig = plt.figure()
ax = fig.add_subplot(111)
f1=ax.plot(x_axis,acc,color='blue',label="acc")
ax2 = ax.twinx()
f2=ax2.plot(x_axis,loss,color='red',label="loss")
f=f1+f2
labs = [l.get_label() for l in f]
ax.legend(f, labs, loc=[0,1])

# %%
def main_corrupt_set():
    # Training settings
    parser = argparse.ArgumentParser(description='PyTorch MNIST Example')
    parser.add_argument('--batch-size', type=int, default=600, metavar='N',
                        help='input batch size for training (default: 256)')
    parser.add_argument('--test-batch-size', type=int, default=4000, metavar='N',
                        help='input batch size for testing (default: 1000)')
    parser.add_argument('--epochs', type=int, default=100, metavar='N',
                        help='number of epochs to train (default: 10)')
    parser.add_argument('--lr', type=float, default=0.005, metavar='LR',
                        help='learning rate (default: 0.01)')
    parser.add_argument('--momentum', type=float, default=0.9, metavar='M',
                        help='SGD momentum (default: 0.5)')
    parser.add_argument('--no-cuda', action='store_true', default=False,
                        help='disables CUDA training')
    parser.add_argument('--seed', type=int, default=1, metavar='S',
                        help='random seed (default: 1)')
    parser.add_argument('--log-interval', type=int, default=100, metavar='N',
                        help='how many batches to wait before logging training status')
    
    parser.add_argument('--save-model', action='store_true', default=False,
                        help='For Saving the current Model')
    args = parser.parse_args()
    use_cuda = not args.no_cuda and torch.cuda.is_available()

    torch.manual_seed(args.seed)

    device = torch.device("cuda" if use_cuda else "cpu")
     
    kwargs = {'num_workers': 4, 'pin_memory': True} if use_cuda else {}
    train_loader = torch.utils.data.DataLoader(
        x_corrupt,
        batch_size=args.batch_size, shuffle=True, **kwargs)
    test_loader = torch.utils.data.DataLoader(
        datasets.MNIST('../data', train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ])),
        batch_size=args.test_batch_size, shuffle=True, **kwargs)
#     train_loader=x

    model = Net().to(device)
    optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)

    acc=[]
    loss=[]
    for epoch in range(1, args.epochs + 1):
        loss.append(train(args, model, device, train_loader, optimizer, epoch))
        acc.append(test(args, model, device, test_loader))
    np.save("acc_corrupt1.npy",acc)
    np.save("loss_corrupt1.npy",loss)
    if (args.save_model):
        torch.save(model.state_dict(),"mnist_cnn1.pt")

# %%
sys.argv = ['-f']
main_corrupt_set()
# Out:
# Train Epoch: 1 [0/48000 (0%)]	Loss: 2.306429
#
# Test set: Average loss: 2.3048, Accuracy: 1410/10000 (14%)
#
# Train Epoch: 2 [0/48000 (0%)]	Loss: 2.305572
#
# Test set: Average loss: 2.3086, Accuracy: 728/10000 (7%)
#
# Train Epoch: 3 [0/48000 (0%)]	Loss: 2.303655
#
# Test set: Average loss: 2.3078, Accuracy: 523/10000 (5%)
#
# Train Epoch: 4 [0/48000 (0%)]	Loss: 2.303049
#
# Test set: Average loss: 2.3078, Accuracy: 785/10000 (8%)
#
# Train Epoch: 5 [0/48000 (0%)]	Loss: 2.300982
#
# Test set: Average loss: 2.3094, Accuracy: 718/10000 (7%)
#
# Train Epoch: 6 [0/48000 (0%)]	Loss: 2.300130
#
# Test set: Average loss: 2.3100, Accuracy: 735/10000 (7%)
#
# Train Epoch: 7 [0/48000 (0%)]	Loss: 2.302365
#
# Test set: Average loss: 2.3112, Accuracy: 537/10000 (5%)
#
# Train Epoch: 8 [0/48000 (0%)]	Loss: 2.298528
#
# Test set: Average loss: 2.3129, Accuracy: 516/10000 (5%)
#
# Train Epoch: 9 [0/48000 (0%)]	Loss: 2.298155
#
# Test set: Average loss: 2.3131, Accuracy: 560/10000 (6%)
#
# Train Epoch: 10 [0/48000 (0%)]	Loss: 2.301642
#
# Test set: Average loss: 2.3135, Accuracy: 699/10000 (7%)
#
# Train Epoch: 11 [0/48000 (0%)]	Loss: 2.297989
#
# Test set: Average loss: 2.3130, Accuracy: 574/10000 (6%)
#
# Train Epoch: 12 [0/48000 (0%)]	Loss: 2.298333
#
# Test set: Average loss: 2.3137, Accuracy: 449/10000 (4%)
#
# Train Epoch: 13 [0/48000 (0%)]	Loss: 2.295482
#
# Test set: Average loss: 2.3138, Accuracy: 405/10000 (4%)
#
# Train Epoch: 14 [0/48000 (0%)]	Loss: 2.293266
#
# Test set: Average loss: 2.3142, Accuracy: 493/10000 (5%)
#
# Train Epoch: 15 [0/48000 (0%)]	Loss: 2.294631
#
# Test set: Average loss: 2.3157, Accuracy: 582/10000 (6%)
#
# Train Epoch: 16 [0/48000 (0%)]	Loss: 2.297144
#
# Test set: Average loss: 2.3139, Accuracy: 580/10000 (6%)
#
# Train Epoch: 17 [0/48000 (0%)]	Loss: 2.295937
#
# Test set: Average loss: 2.3142, Accuracy: 856/10000 (9%)
#
# Train Epoch: 18 [0/48000 (0%)]	Loss: 2.296913
#
# Test set: Average loss: 2.3147, Accuracy: 568/10000 (6%)
#
# Train Epoch: 19 [0/48000 (0%)]	Loss: 2.299121
#
# Test set: Average loss: 2.3158, Accuracy: 475/10000 (5%)
#
# Train Epoch: 20 [0/48000 (0%)]	Loss: 2.299232
#
# Test set: Average loss: 2.3149, Accuracy: 540/10000 (5%)
#
# Train Epoch: 21 [0/48000 (0%)]	Loss: 2.296037
#
# Test set: Average loss: 2.3170, Accuracy: 590/10000 (6%)
#
# Train Epoch: 22 [0/48000 (0%)]	Loss: 2.292572
#
# Test set: Average loss: 2.3136, Accuracy: 789/10000 (8%)
#
# Train Epoch: 23 [0/48000 (0%)]	Loss: 2.298326
#
# Test set: Average loss: 2.3140, Accuracy: 798/10000 (8%)
#
# Train Epoch: 24 [0/48000 (0%)]	Loss: 2.291483
#
# Test set: Average loss: 2.3150, Accuracy: 676/10000 (7%)
#
# Train Epoch: 25 [0/48000 (0%)]	Loss: 2.293289
#
# Test set: Average loss: 2.3167, Accuracy: 766/10000 (8%)
#
# Train Epoch: 26 [0/48000 (0%)]	Loss: 2.291538
#
# Test set: Average loss: 2.3189, Accuracy: 709/10000 (7%)
#
# Train Epoch: 27 [0/48000 (0%)]	Loss: 2.295250
#
# Test set: Average loss: 2.3194, Accuracy: 645/10000 (6%)
#
# Train Epoch: 28 [0/48000 (0%)]	Loss: 2.283259
#
# Test set: Average loss: 2.3223, Accuracy: 633/10000 (6%)
#
# Train Epoch: 29 [0/48000 (0%)]	Loss: 2.300006
#
# Test set: Average loss: 2.3153, Accuracy: 756/10000 (8%)
#
# Train Epoch: 30 [0/48000 (0%)]	Loss: 2.286088
#
# Test set: Average loss: 2.3133, Accuracy: 903/10000 (9%)
#
# Train Epoch: 31 [0/48000 (0%)]	Loss: 2.285419
#
# Test set: Average loss: 2.3150, Accuracy: 815/10000 (8%)
#
# Train Epoch: 32 [0/48000 (0%)]	Loss: 2.280354
#
# Test set: Average loss: 2.3180, Accuracy: 850/10000 (8%)
#
# Train Epoch: 33 [0/48000 (0%)]	Loss: 2.279141
#
# Test set: Average loss: 2.3145, Accuracy: 909/10000 (9%)
#
# Train Epoch: 34 [0/48000 (0%)]	Loss: 2.284364
#
# Test set: Average loss: 2.3121, Accuracy: 962/10000 (10%)
#
# Train Epoch: 35 [0/48000 (0%)]	Loss: 2.283199
#
# Test set: Average loss: 2.3170, Accuracy: 847/10000 (8%)
#
# Train Epoch: 36 [0/48000 (0%)]	Loss: 2.278356
#
# Test set: Average loss: 2.3179, Accuracy: 918/10000 (9%)
#
# Train Epoch: 37 [0/48000 (0%)]	Loss: 2.280372
#
# Test set: Average loss: 2.3192, Accuracy: 835/10000 (8%)
#
# Train Epoch: 38 [0/48000 (0%)]	Loss: 2.283718
#
# Test set: Average loss: 2.3159, Accuracy: 946/10000 (9%)
#
# Train Epoch: 39 [0/48000 (0%)]	Loss: 2.273477
#
# Test set: Average loss: 2.3283, Accuracy: 818/10000 (8%)
#
# Train Epoch: 40 [0/48000 (0%)]	Loss: 2.274424
#
# Test set: Average loss: 2.3102, Accuracy: 809/10000 (8%)
#
# Train Epoch: 41 [0/48000 (0%)]	Loss: 2.267475
#
# Test set: Average loss: 2.3216, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 42 [0/48000 (0%)]	Loss: 2.278848
#
# Test set: Average loss: 2.3189, Accuracy: 913/10000 (9%)
#
# Train Epoch: 43 [0/48000 (0%)]	Loss: 2.274503
#
# Test set: Average loss: 2.3104, Accuracy: 1119/10000 (11%)
#
# Train Epoch: 44 [0/48000 (0%)]	Loss: 2.265830
#
# Test set: Average loss: 2.3151, Accuracy: 1098/10000 (11%)
#
# Train Epoch: 45 [0/48000 (0%)]	Loss: 2.280025
#
# Test set: Average loss: 2.3132, Accuracy: 902/10000 (9%)
#
# Train Epoch: 46 [0/48000 (0%)]	Loss: 2.260686
#
# Test set: Average loss: 2.3156, Accuracy: 1042/10000 (10%)
#
# Train Epoch: 47 [0/48000 (0%)]	Loss: 2.268381
#
# Test set: Average loss: 2.3161, Accuracy: 925/10000 (9%)
#
# Train Epoch: 48 [0/48000 (0%)]	Loss: 2.266339
#
# Test set: Average loss: 2.3377, Accuracy: 772/10000 (8%)
#
# Train Epoch: 49 [0/48000 (0%)]	Loss: 2.262611
#
# Test set: Average loss: 2.3165, Accuracy: 1113/10000 (11%)
#
# Train Epoch: 50 [0/48000 (0%)]	Loss: 2.244302
#
# Test set: Average loss: 2.3204, Accuracy: 1021/10000 (10%)
#
# Train Epoch: 51 [0/48000 (0%)]	Loss: 2.228560
#
# Test set: Average loss: 2.3101, Accuracy: 1251/10000 (13%)
#
# Train Epoch: 52 [0/48000 (0%)]	Loss: 2.250137
#
# Test set: Average loss: 2.3356, Accuracy: 1061/10000 (11%)
#
# Train Epoch: 53 [0/48000 (0%)]	Loss: 2.259230
#
# Test set: Average loss: 2.3365, Accuracy: 880/10000 (9%)
#
# Train Epoch: 54 [0/48000 (0%)]	Loss: 2.241796
#
# Test set: Average loss: 2.3418, Accuracy: 925/10000 (9%)
#
# Train Epoch: 55 [0/48000 (0%)]	Loss: 2.225089
#
# Test set: Average loss: 2.3334, Accuracy: 1017/10000 (10%)
#
# Train Epoch: 56 [0/48000 (0%)]	Loss: 2.244785
#
# Test set: Average loss: 2.3291, Accuracy: 1123/10000 (11%)
#
# Train Epoch: 57 [0/48000 (0%)]	Loss: 2.250001
#
# Test set: Average loss: 2.3171, Accuracy: 1171/10000 (12%)
#
# Train Epoch: 58 [0/48000 (0%)]	Loss: 2.215065
#
# Test set: Average loss: 2.3544, Accuracy: 981/10000 (10%)
#
# Train Epoch: 59 [0/48000 (0%)]	Loss: 2.197584
#
# Test set: Average loss: 2.3389, Accuracy: 1015/10000 (10%)
#
# Train Epoch: 60 [0/48000 (0%)]	Loss: 2.222920
#
# Test set: Average loss: 2.3434, Accuracy: 1020/10000 (10%)
#
# Train Epoch: 61 [0/48000 (0%)]	Loss: 2.220190
#
# Test set: Average loss: 2.3287, Accuracy: 1040/10000 (10%)
#
# Train Epoch: 62 [0/48000 (0%)]	Loss: 2.225976
#
# Test set: Average loss: 2.3183, Accuracy: 1287/10000 (13%)
#
# Train Epoch: 63 [0/48000 (0%)]	Loss: 2.175987
#
# Test set: Average loss: 2.3446, Accuracy: 951/10000 (10%)
#
# Train Epoch: 64 [0/48000 (0%)]	Loss: 2.192586
#
# Test set: Average loss: 2.3781, Accuracy: 890/10000 (9%)
#
# Train Epoch: 65 [0/48000 (0%)]	Loss: 2.217293
#
# Test set: Average loss: 2.3366, Accuracy: 1129/10000 (11%)
#
# Train Epoch: 66 [0/48000 (0%)]	Loss: 2.206672
#
# Test set: Average loss: 2.3681, Accuracy: 1083/10000 (11%)
#
# Train Epoch: 67 [0/48000 (0%)]	Loss: 2.209697
#
# Test set: Average loss: 2.3970, Accuracy: 995/10000 (10%)
#
# Train Epoch: 68 [0/48000 (0%)]	Loss: 2.196989
#
# Test set: Average loss: 2.3390, Accuracy: 1433/10000 (14%)
#
# Train Epoch: 69 [0/48000 (0%)]	Loss: 2.192387
#
# Test set: Average loss: 2.3283, Accuracy: 1282/10000 (13%)
#
# Train Epoch: 70 [0/48000 (0%)]	Loss: 2.179842
#
# Test set: Average loss: 2.4056, Accuracy: 840/10000 (8%)
#
# Train Epoch: 71 [0/48000 (0%)]	Loss: 2.162639
#
# Test set: Average loss: 2.3650, Accuracy: 1253/10000 (13%)
#
# Train Epoch: 72 [0/48000 (0%)]	Loss: 2.156044
#
# Test set: Average loss: 2.4355, Accuracy: 816/10000 (8%)
#
# Train Epoch: 73 [0/48000 (0%)]	Loss: 2.172751
#
# Test set: Average loss: 2.4283, Accuracy: 996/10000 (10%)
#
# Train Epoch: 74 [0/48000 (0%)]	Loss: 2.130276
#
# Test set: Average loss: 2.3640, Accuracy: 1067/10000 (11%)
#
# Train Epoch: 75 [0/48000 (0%)]	Loss: 2.156742
#
# Test set: Average loss: 2.3984, Accuracy: 1025/10000 (10%)
#
# Train Epoch: 76 [0/48000 (0%)]	Loss: 2.145966
#
# Test set: Average loss: 2.4441, Accuracy: 978/10000 (10%)
#
# Train Epoch: 77 [0/48000 (0%)]	Loss: 2.141757
#
# Test set: Average loss: 2.4415, Accuracy: 922/10000 (9%)
#
# Train Epoch: 78 [0/48000 (0%)]	Loss: 2.094468
#
# Test set: Average loss: 2.4279, Accuracy: 938/10000 (9%)
# Train Epoch: 79 [0/48000 (0%)]	Loss: 2.116740
#
# Test set: Average loss: 2.3874, Accuracy: 1271/10000 (13%)
#
# Train Epoch: 80 [0/48000 (0%)]	Loss: 2.082866
#
# Test set: Average loss: 2.4228, Accuracy: 1115/10000 (11%)
#
# Train Epoch: 81 [0/48000 (0%)]	Loss: 2.084755
#
# Test set: Average loss: 2.4683, Accuracy: 1087/10000 (11%)
#
# Train Epoch: 82 [0/48000 (0%)]	Loss: 2.105351
#
# Test set: Average loss: 2.4413, Accuracy: 1064/10000 (11%)
#
# Train Epoch: 83 [0/48000 (0%)]	Loss: 2.047832
#
# Test set: Average loss: 2.5392, Accuracy: 910/10000 (9%)
#
# Train Epoch: 84 [0/48000 (0%)]	Loss: 2.121968
#
# Test set: Average loss: 2.5005, Accuracy: 1011/10000 (10%)
#
# Train Epoch: 85 [0/48000 (0%)]	Loss: 2.044737
#
# Test set: Average loss: 2.4623, Accuracy: 1069/10000 (11%)
#
# Train Epoch: 86 [0/48000 (0%)]	Loss: 2.064298
#
# Test set: Average loss: 2.4307, Accuracy: 1200/10000 (12%)
#
# Train Epoch: 87 [0/48000 (0%)]	Loss: 2.022727
#
# Test set: Average loss: 2.5404, Accuracy: 980/10000 (10%)
#
# Train Epoch: 88 [0/48000 (0%)]	Loss: 2.025808
#
# Test set: Average loss: 2.4637, Accuracy: 1090/10000 (11%)
#
# Train Epoch: 89 [0/48000 (0%)]	Loss: 1.968159
#
# Test set: Average loss: 2.5547, Accuracy: 857/10000 (9%)
#
# Train Epoch: 90 [0/48000 (0%)]	Loss: 1.999464
#
# Test set: Average loss: 2.5413, Accuracy: 925/10000 (9%)
#
# Train Epoch: 91 [0/48000 (0%)]	Loss: 1.993998
#
# Test set: Average loss: 2.4918, Accuracy: 1160/10000 (12%)
#
# Train Epoch: 92 [0/48000 (0%)]	Loss: 1.994887
#
# Test set: Average loss: 2.5947, Accuracy: 969/10000 (10%)
#
# Train Epoch: 93 [0/48000 (0%)]	Loss: 1.981919
#
# Test set: Average loss: 2.5859, Accuracy: 945/10000 (9%)
#
# Train Epoch: 94 [0/48000 (0%)]	Loss: 1.909452
#
# Test set: Average loss: 2.5226, Accuracy: 1102/10000 (11%)
#
# Train Epoch: 95 [0/48000 (0%)]	Loss: 1.925543
#
# Test set: Average loss: 2.5270, Accuracy: 1038/10000 (10%)
#
# Train Epoch: 96 [0/48000 (0%)]	Loss: 1.925865
#
# Test set: Average loss: 2.5535, Accuracy: 1249/10000 (12%)
#
# Train Epoch: 97 [0/48000 (0%)]	Loss: 1.859611
#
# Test set: Average loss: 2.5880, Accuracy: 1181/10000 (12%)
#
# Train Epoch: 98 [0/48000 (0%)]	Loss: 1.932532
#
# Test set: Average loss: 2.5833, Accuracy: 1144/10000 (11%)
#
# Train Epoch: 99 [0/48000 (0%)]	Loss: 1.869486
#
# Test set: Average loss: 2.6279, Accuracy: 1023/10000 (10%)
#
# Train Epoch: 100 [0/48000 (0%)]	Loss: 1.834070
#
# Test set: Average loss: 2.6491, Accuracy: 990/10000 (10%)

# %%
def main_pure_set():
    # Training settings
    parser = argparse.ArgumentParser(description='PyTorch MNIST Example')
    parser.add_argument('--batch-size', type=int, default=600, metavar='N',
                        help='input batch size for training (default: 256)')
    parser.add_argument('--test-batch-size', type=int, default=4000, metavar='N',
                        help='input batch size for testing (default: 1000)')
    parser.add_argument('--epochs', type=int, default=100, metavar='N',
                        help='number of epochs to train (default: 10)')
    parser.add_argument('--lr', type=float, default=0.005, metavar='LR',
                        help='learning rate (default: 0.01)')
    parser.add_argument('--momentum', type=float, default=0.9, metavar='M',
                        help='SGD momentum (default: 0.5)')
    parser.add_argument('--no-cuda', action='store_true', default=False,
                        help='disables CUDA training')
    parser.add_argument('--seed', type=int, default=1, metavar='S',
                        help='random seed (default: 1)')
    parser.add_argument('--log-interval', type=int, default=100, metavar='N',
                        help='how many batches to wait before logging training status')
    
    parser.add_argument('--save-model', action='store_true', default=False,
                        help='For Saving the current Model')
    args = parser.parse_args()
    use_cuda = not args.no_cuda and torch.cuda.is_available()

    torch.manual_seed(args.seed)

    device = torch.device("cuda" if use_cuda else "cpu")
     
    kwargs = {'num_workers': 4, 'pin_memory': True} if use_cuda else {}
    train_loader = torch.utils.data.DataLoader(
        x_pure,
        batch_size=args.batch_size, shuffle=True, **kwargs)
    test_loader = torch.utils.data.DataLoader(
        datasets.MNIST('../data', train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ])),
        batch_size=args.test_batch_size, shuffle=True, **kwargs)
#     train_loader=x

    model = Net().to(device)
    optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)

    acc=[]
    loss=[]
    for epoch in range(1, args.epochs + 1):
        loss.append(train(args, model, device, train_loader, optimizer, epoch))
        acc.append(test(args, model, device, test_loader))
    np.save("acc_pure1.npy",acc)
    np.save("loss_pure1.npy",loss)
    if (args.save_model):
        torch.save(model.state_dict(),"mnist_cnn1.pt")

# %%
sys.argv = ['-f']
main_pure_set()
# Out:
# Train Epoch: 1 [0/12000 (0%)]	Loss: 2.303364
#
# Test set: Average loss: 2.0628, Accuracy: 5873/10000 (59%)
#
# Train Epoch: 2 [0/12000 (0%)]	Loss: 2.055946
#
# Test set: Average loss: 0.9533, Accuracy: 7633/10000 (76%)
#
# Train Epoch: 3 [0/12000 (0%)]	Loss: 0.952204
#
# Test set: Average loss: 0.4601, Accuracy: 8569/10000 (86%)
#
# Train Epoch: 4 [0/12000 (0%)]	Loss: 0.511371
#
# Test set: Average loss: 0.3522, Accuracy: 8895/10000 (89%)
#
# Train Epoch: 5 [0/12000 (0%)]	Loss: 0.374803
#
# Test set: Average loss: 0.2909, Accuracy: 9141/10000 (91%)
#
# Train Epoch: 6 [0/12000 (0%)]	Loss: 0.297305
#
# Test set: Average loss: 0.2577, Accuracy: 9228/10000 (92%)
#
# Train Epoch: 7 [0/12000 (0%)]	Loss: 0.254769
#
# Test set: Average loss: 0.2295, Accuracy: 9326/10000 (93%)
#
# Train Epoch: 8 [0/12000 (0%)]	Loss: 0.277708
#
# Test set: Average loss: 0.2042, Accuracy: 9401/10000 (94%)
#
# Train Epoch: 9 [0/12000 (0%)]	Loss: 0.232820
#
# Test set: Average loss: 0.1930, Accuracy: 9442/10000 (94%)
#
# Train Epoch: 10 [0/12000 (0%)]	Loss: 0.190357
#
# Test set: Average loss: 0.1768, Accuracy: 9482/10000 (95%)
#
# Train Epoch: 11 [0/12000 (0%)]	Loss: 0.186636
#
# Test set: Average loss: 0.1545, Accuracy: 9554/10000 (96%)
#
# Train Epoch: 12 [0/12000 (0%)]	Loss: 0.122401
#
# Test set: Average loss: 0.1420, Accuracy: 9598/10000 (96%)
#
# Train Epoch: 13 [0/12000 (0%)]	Loss: 0.130705
#
# Test set: Average loss: 0.1394, Accuracy: 9617/10000 (96%)
#
# Train Epoch: 14 [0/12000 (0%)]	Loss: 0.107105
#
# Test set: Average loss: 0.1321, Accuracy: 9619/10000 (96%)
#
# Train Epoch: 15 [0/12000 (0%)]	Loss: 0.083966
#
# Test set: Average loss: 0.1208, Accuracy: 9663/10000 (97%)
#
# Train Epoch: 16 [0/12000 (0%)]	Loss: 0.101395
#
# Test set: Average loss: 0.1222, Accuracy: 9634/10000 (96%)
#
# Train Epoch: 17 [0/12000 (0%)]	Loss: 0.096889
#
# Test set: Average loss: 0.1145, Accuracy: 9670/10000 (97%)
#
# Train Epoch: 18 [0/12000 (0%)]	Loss: 0.114457
#
# Test set: Average loss: 0.1144, Accuracy: 9664/10000 (97%)
#
# Train Epoch: 19 [0/12000 (0%)]	Loss: 0.118065
#
# Test set: Average loss: 0.1048, Accuracy: 9683/10000 (97%)
#
# Train Epoch: 20 [0/12000 (0%)]	Loss: 0.090055
#
# Test set: Average loss: 0.0952, Accuracy: 9710/10000 (97%)
#
# Train Epoch: 21 [0/12000 (0%)]	Loss: 0.059963
#
# Test set: Average loss: 0.0951, Accuracy: 9713/10000 (97%)
#
# Train Epoch: 22 [0/12000 (0%)]	Loss: 0.077104
#
# Test set: Average loss: 0.0951, Accuracy: 9712/10000 (97%)
#
# Train Epoch: 23 [0/12000 (0%)]	Loss: 0.085438
#
# Test set: Average loss: 0.0841, Accuracy: 9737/10000 (97%)
#
# Train Epoch: 24 [0/12000 (0%)]	Loss: 0.082413
#
# Test set: Average loss: 0.0832, Accuracy: 9748/10000 (97%)
#
# Train Epoch: 25 [0/12000 (0%)]	Loss: 0.057605
#
# Test set: Average loss: 0.0876, Accuracy: 9744/10000 (97%)
#
# Train Epoch: 26 [0/12000 (0%)]	Loss: 0.083377
#
# Test set: Average loss: 0.0790, Accuracy: 9741/10000 (97%)
#
# Train Epoch: 27 [0/12000 (0%)]	Loss: 0.058018
#
# Test set: Average loss: 0.0791, Accuracy: 9753/10000 (98%)
#
# Train Epoch: 28 [0/12000 (0%)]	Loss: 0.054071
#
# Test set: Average loss: 0.0765, Accuracy: 9768/10000 (98%)
#
# Train Epoch: 29 [0/12000 (0%)]	Loss: 0.060464
#
# Test set: Average loss: 0.0811, Accuracy: 9757/10000 (98%)
#
# Train Epoch: 30 [0/12000 (0%)]	Loss: 0.058289
#
# Test set: Average loss: 0.0740, Accuracy: 9774/10000 (98%)
#
# Train Epoch: 31 [0/12000 (0%)]	Loss: 0.038750
#
# Test set: Average loss: 0.0726, Accuracy: 9783/10000 (98%)
#
# Train Epoch: 32 [0/12000 (0%)]	Loss: 0.044506
#
# Test set: Average loss: 0.0686, Accuracy: 9789/10000 (98%)
#
# Train Epoch: 33 [0/12000 (0%)]	Loss: 0.057365
#
# Test set: Average loss: 0.0711, Accuracy: 9782/10000 (98%)
#
# Train Epoch: 34 [0/12000 (0%)]	Loss: 0.060938
#
# Test set: Average loss: 0.0690, Accuracy: 9780/10000 (98%)
#
# Train Epoch: 35 [0/12000 (0%)]	Loss: 0.039289
#
# Test set: Average loss: 0.0642, Accuracy: 9797/10000 (98%)
#
# Train Epoch: 36 [0/12000 (0%)]	Loss: 0.048238
#
# Test set: Average loss: 0.0659, Accuracy: 9789/10000 (98%)
#
# Train Epoch: 37 [0/12000 (0%)]	Loss: 0.024663
#
# Test set: Average loss: 0.0712, Accuracy: 9769/10000 (98%)
#
# Train Epoch: 38 [0/12000 (0%)]	Loss: 0.042434
#
# Test set: Average loss: 0.0635, Accuracy: 9799/10000 (98%)
#
# Train Epoch: 39 [0/12000 (0%)]	Loss: 0.039923
#
# Test set: Average loss: 0.0632, Accuracy: 9802/10000 (98%)
#
# Train Epoch: 40 [0/12000 (0%)]	Loss: 0.035817
#
# Test set: Average loss: 0.0654, Accuracy: 9793/10000 (98%)
#
# Train Epoch: 41 [0/12000 (0%)]	Loss: 0.027781
#
# Test set: Average loss: 0.0610, Accuracy: 9811/10000 (98%)
#
# Train Epoch: 42 [0/12000 (0%)]	Loss: 0.024096
#
# Test set: Average loss: 0.0662, Accuracy: 9781/10000 (98%)
#
# Train Epoch: 43 [0/12000 (0%)]	Loss: 0.025890
#
# Test set: Average loss: 0.0615, Accuracy: 9793/10000 (98%)
#
# Train Epoch: 44 [0/12000 (0%)]	Loss: 0.046492
#
# Test set: Average loss: 0.0681, Accuracy: 9783/10000 (98%)
#
# Train Epoch: 45 [0/12000 (0%)]	Loss: 0.039476
#
# Test set: Average loss: 0.0628, Accuracy: 9811/10000 (98%)
#
# Train Epoch: 46 [0/12000 (0%)]	Loss: 0.036632
#
# Test set: Average loss: 0.0588, Accuracy: 9815/10000 (98%)
#
# Train Epoch: 47 [0/12000 (0%)]	Loss: 0.025508
#
# Test set: Average loss: 0.0606, Accuracy: 9805/10000 (98%)
#
# Train Epoch: 48 [0/12000 (0%)]	Loss: 0.022976
#
# Test set: Average loss: 0.0622, Accuracy: 9805/10000 (98%)
#
# Train Epoch: 49 [0/12000 (0%)]	Loss: 0.023074
#
# Test set: Average loss: 0.0619, Accuracy: 9791/10000 (98%)
#
# Train Epoch: 50 [0/12000 (0%)]	Loss: 0.029413
#
# Test set: Average loss: 0.0597, Accuracy: 9806/10000 (98%)
#
# Train Epoch: 51 [0/12000 (0%)]	Loss: 0.028484
#
# Test set: Average loss: 0.0614, Accuracy: 9802/10000 (98%)
#
# Train Epoch: 52 [0/12000 (0%)]	Loss: 0.019122
#
# Test set: Average loss: 0.0594, Accuracy: 9822/10000 (98%)
#
# Train Epoch: 53 [0/12000 (0%)]	Loss: 0.044363
#
# Test set: Average loss: 0.0591, Accuracy: 9817/10000 (98%)
#
# Train Epoch: 54 [0/12000 (0%)]	Loss: 0.037539
#
# Test set: Average loss: 0.0583, Accuracy: 9820/10000 (98%)
#
# Train Epoch: 55 [0/12000 (0%)]	Loss: 0.023390
#
# Test set: Average loss: 0.0592, Accuracy: 9797/10000 (98%)
#
# Train Epoch: 56 [0/12000 (0%)]	Loss: 0.017561
#
# Test set: Average loss: 0.0597, Accuracy: 9813/10000 (98%)
#
# Train Epoch: 57 [0/12000 (0%)]	Loss: 0.024444
#
# Test set: Average loss: 0.0563, Accuracy: 9822/10000 (98%)
#
# Train Epoch: 58 [0/12000 (0%)]	Loss: 0.019502
#
# Test set: Average loss: 0.0611, Accuracy: 9811/10000 (98%)
#
# Train Epoch: 59 [0/12000 (0%)]	Loss: 0.011301
#
# Test set: Average loss: 0.0583, Accuracy: 9815/10000 (98%)
#
# Train Epoch: 60 [0/12000 (0%)]	Loss: 0.016157
#
# Test set: Average loss: 0.0547, Accuracy: 9828/10000 (98%)
#
# Train Epoch: 61 [0/12000 (0%)]	Loss: 0.014796
#
# Test set: Average loss: 0.0580, Accuracy: 9819/10000 (98%)
#
# Train Epoch: 62 [0/12000 (0%)]	Loss: 0.022372
#
# Test set: Average loss: 0.0573, Accuracy: 9822/10000 (98%)
#
# Train Epoch: 63 [0/12000 (0%)]	Loss: 0.009728
#
# Test set: Average loss: 0.0580, Accuracy: 9809/10000 (98%)
#
# Train Epoch: 64 [0/12000 (0%)]	Loss: 0.024569
#
# Test set: Average loss: 0.0583, Accuracy: 9814/10000 (98%)
#
# Train Epoch: 65 [0/12000 (0%)]	Loss: 0.018740
#
# Test set: Average loss: 0.0590, Accuracy: 9821/10000 (98%)
#
# Train Epoch: 66 [0/12000 (0%)]	Loss: 0.021531
#
# Test set: Average loss: 0.0560, Accuracy: 9824/10000 (98%)
#
# Train Epoch: 67 [0/12000 (0%)]	Loss: 0.012674
#
# Test set: Average loss: 0.0560, Accuracy: 9821/10000 (98%)
#
# Train Epoch: 68 [0/12000 (0%)]	Loss: 0.014755
#
# Test set: Average loss: 0.0604, Accuracy: 9812/10000 (98%)
#
# Train Epoch: 69 [0/12000 (0%)]	Loss: 0.013576
#
# Test set: Average loss: 0.0575, Accuracy: 9820/10000 (98%)
#
# Train Epoch: 70 [0/12000 (0%)]	Loss: 0.024257
#
# Test set: Average loss: 0.0569, Accuracy: 9823/10000 (98%)
#
# Train Epoch: 71 [0/12000 (0%)]	Loss: 0.011613
#
# Test set: Average loss: 0.0563, Accuracy: 9831/10000 (98%)
#
# Train Epoch: 72 [0/12000 (0%)]	Loss: 0.010565
#
# Test set: Average loss: 0.0545, Accuracy: 9827/10000 (98%)
#
# Train Epoch: 73 [0/12000 (0%)]	Loss: 0.009466
#
# Test set: Average loss: 0.0552, Accuracy: 9834/10000 (98%)
#
# Train Epoch: 74 [0/12000 (0%)]	Loss: 0.009803
#
# Test set: Average loss: 0.0575, Accuracy: 9821/10000 (98%)
#
# Train Epoch: 75 [0/12000 (0%)]	Loss: 0.008739
#
# Test set: Average loss: 0.0544, Accuracy: 9832/10000 (98%)
#
# Train Epoch: 76 [0/12000 (0%)]	Loss: 0.008119
#
# Test set: Average loss: 0.0585, Accuracy: 9825/10000 (98%)
#
# Train Epoch: 77 [0/12000 (0%)]	Loss: 0.012505
#
# Test set: Average loss: 0.0565, Accuracy: 9823/10000 (98%)
# Train Epoch: 78 [0/12000 (0%)]	Loss: 0.012835
#
# Test set: Average loss: 0.0564, Accuracy: 9838/10000 (98%)
#
# Train Epoch: 79 [0/12000 (0%)]	Loss: 0.006972
#
# Test set: Average loss: 0.0554, Accuracy: 9828/10000 (98%)
#
# Train Epoch: 80 [0/12000 (0%)]	Loss: 0.010158
#
# Test set: Average loss: 0.0559, Accuracy: 9832/10000 (98%)
#
# Train Epoch: 81 [0/12000 (0%)]	Loss: 0.009549
#
# Test set: Average loss: 0.0557, Accuracy: 9829/10000 (98%)
#
# Train Epoch: 82 [0/12000 (0%)]	Loss: 0.007927
#
# Test set: Average loss: 0.0539, Accuracy: 9828/10000 (98%)
#
# Train Epoch: 83 [0/12000 (0%)]	Loss: 0.009585
#
# Test set: Average loss: 0.0552, Accuracy: 9829/10000 (98%)
#
# Train Epoch: 84 [0/12000 (0%)]	Loss: 0.011731
#
# Test set: Average loss: 0.0544, Accuracy: 9831/10000 (98%)
#
# Train Epoch: 85 [0/12000 (0%)]	Loss: 0.008095
#
# Test set: Average loss: 0.0545, Accuracy: 9822/10000 (98%)
#
# Train Epoch: 86 [0/12000 (0%)]	Loss: 0.007812
#
# Test set: Average loss: 0.0545, Accuracy: 9832/10000 (98%)
#
# Train Epoch: 87 [0/12000 (0%)]	Loss: 0.005565
#
# Test set: Average loss: 0.0577, Accuracy: 9828/10000 (98%)
#
# Train Epoch: 88 [0/12000 (0%)]	Loss: 0.009996
#
# Test set: Average loss: 0.0547, Accuracy: 9835/10000 (98%)
#
# Train Epoch: 89 [0/12000 (0%)]	Loss: 0.005056
#
# Test set: Average loss: 0.0566, Accuracy: 9830/10000 (98%)
#
# Train Epoch: 90 [0/12000 (0%)]	Loss: 0.006244
#
# Test set: Average loss: 0.0573, Accuracy: 9825/10000 (98%)
#
# Train Epoch: 91 [0/12000 (0%)]	Loss: 0.006667
#
# Test set: Average loss: 0.0559, Accuracy: 9836/10000 (98%)
#
# Train Epoch: 92 [0/12000 (0%)]	Loss: 0.006188
#
# Test set: Average loss: 0.0557, Accuracy: 9836/10000 (98%)
#
# Train Epoch: 93 [0/12000 (0%)]	Loss: 0.006585
#
# Test set: Average loss: 0.0568, Accuracy: 9826/10000 (98%)
#
# Train Epoch: 94 [0/12000 (0%)]	Loss: 0.011650
#
# Test set: Average loss: 0.0544, Accuracy: 9832/10000 (98%)
#
# Train Epoch: 95 [0/12000 (0%)]	Loss: 0.004132
#
# Test set: Average loss: 0.0552, Accuracy: 9836/10000 (98%)
#
# Train Epoch: 96 [0/12000 (0%)]	Loss: 0.004012
#
# Test set: Average loss: 0.0575, Accuracy: 9828/10000 (98%)
#
# Train Epoch: 97 [0/12000 (0%)]	Loss: 0.005916
#
# Test set: Average loss: 0.0583, Accuracy: 9831/10000 (98%)
#
# Train Epoch: 98 [0/12000 (0%)]	Loss: 0.008804
#
# Test set: Average loss: 0.0558, Accuracy: 9836/10000 (98%)
#
# Train Epoch: 99 [0/12000 (0%)]	Loss: 0.006366
#
# Test set: Average loss: 0.0562, Accuracy: 9823/10000 (98%)
#
# Train Epoch: 100 [0/12000 (0%)]	Loss: 0.007689
#
# Test set: Average loss: 0.0557, Accuracy: 9835/10000 (98%)

# %%
acc=np.load("acc.npy")
x_axis=np.arange(100)
loss=np.load("loss.npy")
loss_corrupt=np.load("loss_corrupt.npy")
loss_pure=np.load("loss_pure.npy")

# %%
fig = plt.figure(figsize=(20,12))
ax = fig.add_subplot(111)
f1=ax.plot(x_axis,acc,color='blue',label="acc",lw=6)
ax2 = ax.twinx()
f2=ax2.plot(x_axis,loss,color='red',label="loss",ls='dashed')
f3=ax2.plot(x_axis,loss_pure,color='purple',label="loss_pure")
f4=ax2.plot(x_axis,loss_corrupt,color='green',label="loss_corrupt")
f=f1+f2+f3+f4
labs = [l.get_label() for l in f]
ax.legend(f, labs, loc=[1.2, 0.5],prop={'size': 50})
