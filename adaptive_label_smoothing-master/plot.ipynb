# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
acc=np.load("acc.npy")
x_axis=np.arange(100)
loss=np.load("loss.npy")
loss_corrupt=np.load("loss_corrupt.npy")
loss_pure=np.load("loss_pure.npy")

# %%
fig = plt.figure(figsize=(20,12))
ax = fig.add_subplot(111)
f1=ax.plot(x_axis,acc,color='blue',label="acc",lw=6)
ax2 = ax.twinx()
f2=ax2.plot(x_axis,loss,color='red',label="loss",ls='dashed')
f3=ax2.plot(x_axis,loss_pure,color='purple',label="loss_pure")
f4=ax2.plot(x_axis,loss_corrupt,color='green',label="loss_corrupt")
f=f1+f2+f3+f4
labs = [l.get_label() for l in f]
ax.legend(f, labs, loc=[1.2, 0.5],prop={'size': 50})

# %%
acc=np.load("acc1.npy")
x_axis=np.arange(100)
loss=np.load("loss1.npy")
loss_corrupt=np.load("loss_corrupt1.npy")
loss_pure=np.load("loss_pure1.npy")

# %%
fig = plt.figure(figsize=(20,12))
ax = fig.add_subplot(111)
f1=ax.plot(x_axis,acc,color='blue',label="acc",lw=6)
ax2 = ax.twinx()
f2=ax2.plot(x_axis,loss,color='red',label="loss",ls='dashed')
f3=ax2.plot(x_axis,loss_pure,color='purple',label="loss_pure")
f4=ax2.plot(x_axis,loss_corrupt,color='green',label="loss_corrupt")
f=f1+f2+f3+f4
labs = [l.get_label() for l in f]
ax.legend(f, labs, loc=[1.2, 0.5],prop={'size': 50})

# %%
acc_raw=np.load("acc.npy")
acc_mod=np.load("acc1.npy")
acc_upp=np.load("acc_p.npy")
x_axis=np.arange(100)
fig = plt.figure(figsize=(20,12))
plt.plot(x_axis,acc_raw,color='green',label="original_acc",lw=6)
plt.plot(x_axis,acc_mod,color='blue',label="modified_loss_acc",lw=6)
plt.plot(x_axis,acc_upp,color='red',label="upper_bound_acc",lw=6)
plt.legend(loc=[1.2, 0.5],prop={'size': 50})
